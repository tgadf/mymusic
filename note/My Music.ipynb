# %% [markdown]
# # My Music

# %%
## Basic stuff
# %load_ext autoreload
# %autoreload
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("""<style>div.output_area{max-height:10000px;overflow:scroll;}</style>"""))


##################################################################################################################
# Music Code
##################################################################################################################
from masterDBGate import masterDBGate
from mp3id import mp3ID
from musicPath import pathBasics


##################################################################################################################
# Utils
##################################################################################################################
from searchUtils import findDirsPattern, findWalkExt
from fileUtils import getBaseFilename, getFileBasics
from fsUtils import setFile
from ioUtils import saveFile, getFile
from timeUtils import timestat


##################################################################################################################
# General Python
##################################################################################################################
from time import sleep
from pandas import DataFrame, Series


##################################################################################################################
# System
##################################################################################################################
import sys
print("Python: {0}".format(sys.version))

import datetime as dt
start = dt.datetime.now()
print("Notebook Last Run Initiated: "+str(start))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>.container { width:100% !important; }</style>
# <style>div.output_area{max-height:10000px;overflow:scroll;}</style>
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/j1/syf62l4j46q052mwy0366byh0000gn/T/ipykernel_10285/3545894219.py in <module>
#      12 from masterDBGate import masterDBGate
#      13 from mp3id import mp3ID
# ---> 14 from musicPath import pathBasics
#      15
#      16
#
# ~/Documents/code310/music/musicPath.py in <module>
#       1 from fileUtils import getBaseFilename, getDirname, getExt, getBasename
#       2 from fsUtils import setDir, isFile
# ----> 3 from musicBase import musicBase
#       4
#       5 class pbClass:
#
# ImportError: cannot import name 'musicBase' from 'musicBase' (/Users/tgadfort/Documents/code310/music/musicBase.py)

# %% [markdown]
# # Music Analyzer (My Music)

# %%
# %load_ext autoreload
# %autoreload


##############################################################################################################################
# My Music
##############################################################################################################################
class musicAnalyzer(musicBase):
    def __init__(self, debug=False):
        self.name = "myanalyzer"
        musicBase.__init__(self, debug=debug)
        
        self.pb      = pathBasics()
        self.flists  = self.getMusicListFiles()
        self.tagDBs  = self.getMusicTagDBs()
        self.pathDBs = self.getMusicPathDBs()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def realName(x):
    if x is None:
        return [None,-1]
    
    lenx = len(x)
    if len(x) < 1:
        return [x,-1]

    if x[-1] != ")":
        return [x, None]
    

    if lenx >=5:
        if x[-3] == "(":
            try:
                num = int(x[-2:-1])
                val = x[:-3].strip()
                return [val, num]
            except:
                return [x, None]
            
    if lenx >= 6:
        if x[-4] == "(":
            try:
                num = int(x[-3:-1])
                val = x[:-4].strip()
                return [val, num]
            except:
                return [x, None]
            
    if lenx >= 7:
        if x[-4] == "(":
            try:
                num = int(x[-3:-1])
                val = x[:-4].strip()
                return [val, num]
            except:
                return [x, None]

    return [x, None]

# %%
from pandas import Series
discdf = DataFrame(Series(df))
discdf.columns = ['Name']
tmp = DataFrame(discdf["Name"].apply(realName).tolist())
tmp.index = discdf.index
discdf['Artist'] = tmp[0]

discdf = discdf[~discdf['Name'].isna()]
print(discdf.shape)

artists = list(discdf["Artist"])

_ = clock("Last Run")
# Out:
# (544415, 2)
# Current Time is Mon Oct 21, 2019 17:12:25 for Last Run

# %%
# %load_ext autoreload
# %autoreload
mf = musicFinder(debug=False)
## Run This To Find Music Paths
mf.findMusic() #"Soundtrack", "Live", "Classical", "Jazz", "MixTape", "Compilation", "Non Fiction", "Todo", "Moves", "Not In Discogs"])
ma = musicAnalyzer(debug=False)

_ = clock("Last Run")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ['/Volumes/Music/Classical', '/Volumes/Music/Downloads', '/Volumes/Music/Live', '/Volumes/Music/MixTape', '/Volumes/Music/Non Fiction', '/Volumes/Music/ToDo', '/Volumes/Music/Compilation', '/Volumes/Music/Jazz', '/Volumes/Music/Matched', '/Volumes/Music/Not In Discogs', '/Volumes/Music/Soundtracks']
# Checking /Volumes/Music/Classical...   	Found 3414 files.
# Processed 3414 paths.
# Saving data to /Volumes/Music/MusicDB/Music-Classical.p
#   --> This file is 154.2kB.
# Saved data to /Volumes/Music/MusicDB/Music-Classical.p
#   --> This file is 154.2kB.
# Checking /Volumes/Music/Downloads...   	Found 0 files.
# Processed 0 paths.
# Saving data to /Volumes/Music/MusicDB/Music-Downloads.p
#   --> This file is 14B.
# Saved data to /Volumes/Music/MusicDB/Music-Downloads.p
#   --> This file is 14B.
# Checking /Volumes/Music/Live...   	Found 122687 files.
# Processed 122687 paths.
# Saving data to /Volumes/Music/MusicDB/Music-Live.p
#   --> This file is 4.7MB.
# Saved data to /Volumes/Music/MusicDB/Music-Live.p
#   --> This file is 4.7MB.
# Checking /Volumes/Music/MixTape...   	Found 8467 files.
# Processed 8467 paths.
# Saving data to /Volumes/Music/MusicDB/Music-MixTape.p
#   --> This file is 453.8kB.
# Saved data to /Volumes/Music/MusicDB/Music-MixTape.p
#   --> This file is 453.8kB.
# Checking /Volumes/Music/Non Fiction...   	Found 461 files.
# Processed 461 paths.
# Saving data to /Volumes/Music/MusicDB/Music-Non Fiction.p
#   --> This file is 17.2kB.
# Saved data to /Volumes/Music/MusicDB/Music-Non Fiction.p
#   --> This file is 17.2kB.
# Checking /Volumes/Music/ToDo...   	Found 10534 files.
# Processed 10534 paths.
# Saving data to /Volumes/Music/MusicDB/Music-ToDo.p
#   --> This file is 426.1kB.
# Saved data to /Volumes/Music/MusicDB/Music-ToDo.p
#   --> This file is 426.1kB.
# Checking /Volumes/Music/Compilation...   	Found 33722 files.
# Processed 33722 paths.
# Saving data to /Volumes/Music/MusicDB/Music-Compilation.p
#   --> This file is 1.8MB.
# Saved data to /Volumes/Music/MusicDB/Music-Compilation.p
#   --> This file is 1.8MB.
# Checking /Volumes/Music/Jazz...   	Found 3747 files.
# Processed 3747 paths.
# Saving data to /Volumes/Music/MusicDB/Music-Jazz.p
#   --> This file is 166.9kB.
# Saved data to /Volumes/Music/MusicDB/Music-Jazz.p
#   --> This file is 166.9kB.
# Checking /Volumes/Music/Matched...   	Found 206198 files.
# Processed 206198 paths.
# Saving data to /Volumes/Music/MusicDB/Music-Matched.p
#   --> This file is 9.3MB.
# Saved data to /Volumes/Music/MusicDB/Music-Matched.p
#   --> This file is 9.3MB.
# Checking /Volumes/Music/Not In Discogs...   	Found 244 files.
# Processed 244 paths.
# Saving data to /Volumes/Music/MusicDB/Music-Not In Discogs.p
#   --> This file is 12.0kB.
# Saved data to /Volumes/Music/MusicDB/Music-Not In Discogs.p
#   --> This file is 12.0kB.
# Checking /Volumes/Music/Soundtracks...   	Found 3092 files.
# Processed 3092 paths.
# Saving data to /Volumes/Music/MusicDB/Music-Soundtracks.p
#   --> This file is 149.7kB.
# Saved data to /Volumes/Music/MusicDB/Music-Soundtracks.p
#   --> This file is 149.7kB.
# Found 24 List Files
# Found 0 DB Files
# Found 19 DB Files
# Current Time is Sat Nov 09, 2019 10:43:28 for Last Run

# %%
start, cmt = clock("Getting My Artists/Albums")

artistData = {}
albumData = {}
for pathfile in ma.pathDBs:
#    if sum([x in pathfile for x in ["Soundtrack", "Live", "Classical", "Jazz", "MixTape", "Compilation", "Non Fiction", "Todo", "Moves", "Not In Discogs"]]) > 0:
#        continue
#    if sum([x in pathfile for x in ["Matched"]]) == 0:
#        continue
    pathdata = getFile(pathfile)
    for mp3,mp3data in pathdata.items():
        if artistData.get(mp3data['pbArtist']) is None:
            artistData[mp3data["pbArtist"]] = {}
        if artistData[mp3data["pbArtist"]].get(mp3data["pbAlbum"]) is None:
            artistData[mp3data["pbArtist"]][mp3data["pbAlbum"]] = []
        artistData[mp3data["pbArtist"]][mp3data["pbAlbum"]].append(mp3)

        if albumData.get(mp3data["pbAlbum"]) is None:
            albumData[mp3data["pbAlbum"]] = {}
        if albumData[mp3data["pbAlbum"]].get(mp3data["pbArtist"]) is None:
            albumData[mp3data["pbAlbum"]][mp3data["pbArtist"]] = []
        albumData[mp3data["pbAlbum"]][mp3data["pbArtist"]].append(mp3)
        
    print("Found {0} artists and {1} albums".format(len(artistData), len(albumData)))
    
    
saveFile(idata=artistData, ifile="/Volumes/Music/MusicDB/artistData.p")
saveFile(idata=albumData, ifile="/Volumes/Music/MusicDB/albumData.p")

elapsed(start, cmt)



_ = clock("Last Run")
# Out:
# Current Time is Sat Nov 09, 2019 10:48:19 for Getting My Artists/Albums
# Found 2 artists and 55 albums
# Found 7 artists and 711 albums
# Found 7 artists and 711 albums
# Found 60 artists and 985 albums
# Found 700 artists and 15713 albums
# Found 721 artists and 16009 albums
# Found 878 artists and 22793 albums
# Found 6063 artists and 38451 albums
# Found 6341 artists and 38826 albums
# Found 6375 artists and 38869 albums
# Found 6412 artists and 38895 albums
# Found 6413 artists and 38912 albums
# Found 6413 artists and 39025 albums
# Found 6446 artists and 43332 albums
# Found 6447 artists and 43597 albums
# Found 6448 artists and 43628 albums
# Found 6449 artists and 43662 albums
# Found 6454 artists and 43844 albums
# Found 6464 artists and 43916 albums
#   --> This file is 14.2MB.
#   --> This file is 14.5MB.
# Current Time is Sat Nov 09, 2019 10:49:22 for Done with Getting My Artists/Albums
# Process [{0}] took 1.1 minutes.
# Current Time is Sat Nov 09, 2019 10:49:22 for Last Run

# %% [markdown]
# # Find Artists

# %%
disc = discogs()
df = disc.getArtistIDToNameData()
tmp = Series(df).apply(realName).tolist()
artists = list(DataFrame(tmp)[0])
# Out:
# Saved Discog Directory /Volumes/Music/Discog is Available
# Local Discog Directory /Users/tgadfort/Music/Discog is Available
# /Volumes/Music/Discog/base exists
# /Volumes/Music/Discog/collections exists
# /Volumes/Music/Discog/artists exists
# /Volumes/Music/Discog/albums exists
# /Volumes/Music/Discog/base-db exists
# /Volumes/Music/Discog/collections-db exists
# /Volumes/Music/Discog/artists-db exists
# /Volumes/Music/Discog/albums-db exists
# /Volumes/Music/Discog/artists-extra exists
# /Volumes/Music/Discog/search exists
# /Volumes/Music/Discog/search-artists exists
# /Volumes/Music/Discog/special exists
# /Volumes/Music/Discog/artist-special exists
# /Volumes/Music/Discog/db exists
# Found 100 artist DB files and that is equal to the max mod value
# Loading data from /Volumes/Music/Discog/db/ArtistIDToName.p
#   --> This file is 10.3MB.
# Loading /Volumes/Music/Discog/db/ArtistIDToName.p
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-72cd40eb347e> in <module>
#       1 disc = discogs()
#       2 df = disc.getArtistIDToNameData()
# ----> 3 tmp = Series(df).apply(realName).tolist()
#       4 artists = list(DataFrame(tmp)[0])
#
# NameError: name 'realName' is not defined

# %%
from searchUtils import findNearest
from unicodedata import normalize
from pandas import DataFrame

def getMusicData(key, artist):
    retval = discdf[discdf[key] == artist]
    if retval.shape[0] > 0:
        return retval
    else:
        return None


saveArtistData = {"Odd": {}, "Match": {}, "Near": {}, "None": {}}

for artistName,artistAlbums in artistData.items():
    
    rename = None
    if False:
        rename = None
        if renameReplacements.get(artistName) is not None:
            artistName = renameReplacements[artistName]
            rename = True
        
    
    artistName = normalize('NFC', artistName)

    
    keys = ["Artist", "Name"]
    done = False
    for key in keys:
        mdata = getMusicData(key, artistName)
        if isinstance(mdata, DataFrame):
            if key == "Artist":
                #print('Match\t',mdata.shape,'\t',artistName)
                saveArtistData["Match"][artistName] = {"Match": artistName, "Rename": rename, "Discog": mdata, "Albums": artistAlbums}
            else:
                print('Odd\t',mdata.shape,'\t',artistName)
                saveArtistData["Odd"][artistName] = {"Match": artistName, "Rename": rename, "Discog": mdata, "Albums": artistAlbums}
            done = True
            break
    if done:
        continue

    cutoff=0.9
    if len(artistName) <= 6:
        cutoff = 0.8
    cutoffArtists = findNearest(item=artistName, ilist=artists, num=1, cutoff=cutoff)
    if len(cutoffArtists) > 0:
        for artist in cutoffArtists:
            mdata = getMusicData("Artist", artist)
            saveArtistData["Near"][artistName] = {"Match": artist, "Rename": rename, "Discog": mdata, "Albums": artistAlbums}
            print('Near','\t',mdata.shape,'\t',artistName,'\t\t====> Discog Match =',artist)
            done = True
    else:
        if False:
            cutoffArtists = findNearest(item=artistName, ilist=artists, num=1, cutoff=cutoff - 0.15)
            if len(cutoffArtists) > 0:
                for artist in cutoffArtists:
                    mdata = getMusicData("Artist", artist)
                    saveArtistData["Near"][artistName] = {"Match": artist, "Rename": rename, "Discog": mdata, "Albums": artistAlbums}
                    print('Near','\t',mdata.shape,'\t',artistName,'\t\t====> Discog Match =',artist)
                    done = True

        
    if done:
        continue
        
    print('\t','\t','\t',artistName)
    saveArtistData["None"][artistName] = {"Match": None, "Rename": rename, "Discog": None, "Albums": artistAlbums}
    continue
    
    
    if artistName == "Anorexia Nervosa (2)":
        print(artistAlbums)
        1/0
    continue
    for albumName,albumVals in artistAlbums.items():
        print("\t",albumName,len(albumVals))    
    break
#albumData = {}
# Out:
# Near 	 (1, 2) 	  ...And Oceans 		====> Discog Match = ...And Oceans
# Near 	 (1, 2) 	 1-2 Japanese 		====> Discog Match = 1/2 Japanese
# 	 	 	 2Pac & Outlawz
# 	 	 	 3rd House
# 	 	 	 A.R. Rahman & The Pussycat Dolls
# Near 	 (1, 2) 	 AC-DC 		====> Discog Match = ACxDC
# Near 	 (1, 2) 	 ACDC 		====> Discog Match = ACxDC
# 	 	 	 Adam & The Ants
# 	 	 	 Afrika Bambaataa & James Brown
# 	 	 	 Alan Licht & Loren Mazzacane Connors
# 	 	 	 Ali Vegas & L-Gee
# 	 	 	 Alice Coltrane & Carlos Santana
# 	 	 	 And Oceans
# 	 	 	 Andreas Ammer & F.M. Einheit & Ulrike Haage
# 	 	 	 Andreas Ammer & FM Einheit & Ulrike Haage
# 	 	 	 Ani DiFranco & Utah Phillips
# 	 	 	 Anne Sofie Von Otter & Elvis Costello
# 	 	 	 Antonio Testa & Alio Die
# 	 	 	 Aretha Franklin & George Michael
# 	 	 	 B.B. King & Eric Clapton
# 	 	 	 B.K.S..S
# 	 	 	 Bad Seeds & Zakary Thaks
# 	 	 	 Belle & Sebastian & Norah Jones
# 	 	 	 Ben Harper & The Blind Boys Of Alabama
# 	 	 	 Ben Webster & Oscar Peterson
# 	 	 	 Benny Andersen & Poul Dissing
# 	 	 	 Billy Bragg & Wilco
# 	 	 	 Billy Childish & Dan Melchior
# 	 	 	 Billy Joel & Richard Joo
# 	 	 	 Birdman & Lil Wayne
# 	 	 	 Birdman & Mack Maine
# 	 	 	 Bluegrass 2001
# 	 	 	 Blues Brothers
# 	 	 	 Blumchen
# 	 	 	 Bob Dylan & Johnny Cash
# 	 	 	 Bob Kogut & Dana Kogut
# 	 	 	 Bob Nanna & Elizabeth Elmore
# 	 	 	 Bobby Osborne & Jesse McReynolds
# 	 	 	 Bobby Pickett + Crypt Kickers
# 	 	 	 Bon Scott & Fraternity
# Odd	 (1, 2) 	 Boris (3)
# 	 	 	 Brian Eno & David Byrne
# 	 	 	 Brian Setzer & The Nashvillains
# 	 	 	 Brooklyn Heights
# 	 	 	 Bruce Joyner & The Unknowns
# 	 	 	 Buddy Guy & Jonny Lang
# 	 	 	 Burnt By The Sun & Luddite Clone
# 	 	 	 Butch Baldassari & John Carlini
# 	 	 	 Camron Silver
# Odd	 (1, 2) 	 Canvas (4)
# 	 	 	 Capital 2
# 	 	 	 Carlos Santana & Buddy Miles
# 	 	 	 Caspar Brötzmann & Page Hamilton
# Odd	 (1, 2) 	 Catastrophic (2)
# 	 	 	 Céline Dion & R. Kelly
# 	 	 	 Charlie Haden & Hank Jones
# 	 	 	 Charlie Waller And The Country Gentlemen
# 	 	 	 China White & Flyboys
# 	 	 	 Chip tha Ripper
# 	 	 	 Chris Brown & Tyga
# 	 	 	 Chris Con Carne
# Odd	 (1, 2) 	 Churn (4)
# 	 	 	 Clinton Sparks & DJ Snake & Pitbull
# Odd	 (1, 2) 	 Co-Ed (2)
# 	 	 	 Coldplay & Jay-Z
# Odd	 (1, 2) 	 Cranium (4)
# Odd	 (1, 2) 	 Cream (2)
# Odd	 (1, 2) 	 Crisis (8)
# 	 	 	 Cyber-Tec
# 	 	 	 D.O.N.S..S
# 	 	 	 Dame Grease & DJ Delz
# 	 	 	 Dan Hicks And The Hot Licks
# 	 	 	 Dance Brothers
# 	 	 	 David Archuleta & David Cook
# 	 	 	 Daz Dillinger & DJ Nik Bean
# 	 	 	 Dearest, Crown
# Odd	 (1, 2) 	 Diamond Head (2)
# 	 	 	 Diana Ross & The Supremes & The Temptations
# 	 	 	 Dire Straits & Jamiroquai
# 	 	 	 Dispatch & O.A.R
# 	 	 	 DJ Drama & Big K.R.I.T.
# 	 	 	 DJ Drama & Le$
# 	 	 	 DJ J-Period & John Legend & The Roots
# 	 	 	 DJ J-Period & Nas
# 	 	 	 DJ Jazzy Jeff & Mick Boogie
# 	 	 	 DJ Keyz & Jadakiss
# 	 	 	 DJ LRM & Keyz
# 	 	 	 DJ Snake & Lil' Jon
# 	 	 	 DJ Spinna & Bobbito
# 	 	 	 DJ Spinz & DJ Pretty Boy Tank
# 	 	 	 Dodo & The Dodo's
# 	 	 	 Dolla & T-Pain & Akon
# 	 	 	 Dolly Parton & Kenny Rogers
# 	 	 	 Dolly Parton & Linda Ronstadt & Emmylou Harris
# 	 	 	 Don Cherry & Willie Nelson
# 	 	 	 Don Edwards & Waddie Mitchell
# 	 	 	 Don Henley & Patty Smith
# 	 	 	 Donell Jones & Left Eye
# 	 	 	 Donovan Duke
# 	 	 	 Doug Cloud And County Line
# 	 	 	 Dougie F
# 	 	 	 Down By Law & Pseudo Heroes
# 	 	 	 Dr. Alban & Haddaway
# Odd	 (1, 2) 	 Drunk (2)
# 	 	 	 Echoes Of Nature
# 	 	 	 Eclectics And Friends
# 	 	 	 Ed Sheeran & Yelawolf
# 	 	 	 Eddie Amado & Ian Poole
# 	 	 	 Eddie Boyd & Fleetwood Mac
# Odd	 (1, 2) 	 Electric Wizard (2)
# Near 	 (1, 2) 	 Elliott Sharp : Carbon 		====> Discog Match = Elliott Sharp / Carbon
# 	 	 	 Elton John & kd Lang
# 	 	 	 Elvira, Mistress of the Dark
# 	 	 	 Elvis Costello & Bill Frisell
# 	 	 	 Elvis Costello & Brodsky Quartet
# 	 	 	 Elvis Costello & Burt Bacharach
# 	 	 	 Emerson & Newton
# 	 	 	 Eminem & 50 Cent
# Near 	 (1, 2) 	 Eminem & Elton John 		====> Discog Match = Eminem Vs Elton John
# 	 	 	 Emmylou Harris & Rodney Crowell
# Odd	 (1, 2) 	 Emperor (2)
# Odd	 (1, 2) 	 Engine (5)
# Odd	 (1, 2) 	 Ennui (4)
# 	 	 	 Enrique Iglesias & Alsou
# 	 	 	 Enrique Iglesias & Nâdiya
# Odd	 (1, 2) 	 Eraserheads (3)
# 	 	 	 Eric Clapton & B.B. King
# Odd	 (1, 2) 	 Eric Thompson (4)
# Odd	 (1, 2) 	 Eterne (2)
# 	 	 	 Eugene Chadbourne & Evan Johns
# 	 	 	 Evil Empire & The Coke Boys
# Odd	 (1, 2) 	 Extreme (2)
# 	 	 	 Extreme Noise Terror & Filthkick
# 	 	 	 Fair River Station
# 	 	 	 Falling Forward & Metroschifter
# Odd	 (1, 2) 	 False Prophets (2)
# 	 	 	 Fatboy Slim & Leftfield
# Odd	 (1, 2) 	 Fergie (2)
# Near 	 (2, 2) 	 Filibuste 		====> Discog Match = Filibuster
# 	 	 	 Flip-Side
# 	 	 	 Flowchart & Her Space Holiday
# 	 	 	 Flowchart & Smothered In Hugs
# Near 	 (1, 2) 	 Frank Lini 		====> Discog Match = Frank Lion
# 	 	 	 Frank Sinatra & Tommy Dorsey
# 	 	 	 Frank Wakefield & The Good Old Boys
# 	 	 	 Frankie Valli & The Four Seasons
# 	 	 	 Frankie Valli And The Four Seasons
# 	 	 	 French Montana & Chinx
# Odd	 (1, 2) 	 Fuel (3)
# 	 	 	 Future Sound of London
# 	 	 	 Gary William Friedman & Will Holt
# 	 	 	 Genesis P-Orridge & Splinter Test
# 	 	 	 George Michael & Elton John
# 	 	 	 George Michael & Mary J. Blige
# 	 	 	 George Michael & Mutya Buena
# 	 	 	 George Michael & Queen & Lisa Stansfield
# Odd	 (1, 2) 	 Geraldine (8)
# 	 	 	 Ghostface Killah & DJ Premier
# 	 	 	 Ghostface Killah & Trife Da God*
# 	 	 	 Ghostface Killah & Wu-Tang Clan
# 	 	 	 Giant's Chair & Boys Life
# 	 	 	 Glenn Yarbrough & The Limeliters
# 	 	 	 Glo And Joe
# 	 	 	 Gloria Estefan & Miami Sound Machine
# Odd	 (1, 2) 	 Gnome (2)
# 	 	 	 GoGoGo Airheart And Los Cincos
# 	 	 	 Good Riddance And Kill Your Idols
# 	 	 	 Gorillaz & D12
# Odd	 (1, 2) 	 Grade (2)
# Odd	 (1, 2) 	 Griffin (3)
# 	 	 	 Gucci Mane & Young Scooter
# Odd	 (1, 2) 	 Guilt (2)
# Odd	 (1, 2) 	 Hades (2)
# 	 	 	 Harvey & The Moonglows
# Odd	 (1, 2) 	 Harvey Danger (2)
# Odd	 (1, 2) 	 Haymarket Riot (2)
# Odd	 (1, 2) 	 Headlock (2)
# 	 	 	 Heidi Grant Murphy & Aureole
# Odd	 (1, 2) 	 Helium (3)
# 	 	 	 Helmet & House Of Pain
# Odd	 (1, 2) 	 Helmet (2)
# Odd	 (1, 2) 	 Hem (2)
# 	 	 	 Hickory Tenpin
# Odd	 (1, 2) 	 Hinder (2)
# 	 	 	 Hitch Hiker & Dumont
# 	 	 	 Hodgy Beats & Don Cannon
# Odd	 (1, 2) 	 Hole (2)
# 	 	 	 Holly Golightly & Dan Melchior
# Odd	 (1, 2) 	 Horsey (2)
# 	 	 	 Hot Styles
# 	 	 	 House not House
# 	 	 	 House Of Pain And Everlast
# 	 	 	 Hugh Martin & Ralph Blane
# 	 	 	 Hugh Martin & Timothy Gray
# 	 	 	 Ian Boom
# Odd	 (1, 2) 	 Ikon (4)
# Odd	 (1, 2) 	 In Cold Blood (2)
# Odd	 (1, 2) 	 Incubus (2)
# Odd	 (1, 2) 	 Indecision (2)
# Odd	 (1, 2) 	 Inhuman (3)
# 	 	 	 Inside IN
# 	 	 	 Integrity & Fear Tomorrow
# Odd	 (1, 2) 	 Integrity (2)
# 	 	 	 Intro To Airlift & June Panic
# 	 	 	 INXS & Jimmy Barnes
# Odd	 (1, 2) 	 Iron Monkey (3)
# 	 	 	 J. Armz & AraabMuzik
# 	 	 	 J. Period & Michael Jackson
# 	 	 	 J. Period X Nate Dogg
# Odd	 (1, 2) 	 Jackhammer (8)
# 	 	 	 Jae Millz & Evil Empire
# Odd	 (1, 2) 	 James Taylor (2)
# 	 	 	 Jason Bill & Jack Rose
# 	 	 	 Jay-Z & Kanye West
# 	 	 	 Jay-Z & Linkin Park
# 	 	 	 Jeff Autry & Wayne Benson & Aubrey Haynie & Randy Kohrs & Mark Schatz & Scott Vestal
# 	 	 	 Jeff Ott & Amanda
# 	 	 	 Jerry Lee Lewis & Carl Perkins
# 	 	 	 Jessie J, Ariana Grande & Nicki Minaj
# 	 	 	 Jestofunk & Cinda
# 	 	 	 Jim Hurst & Missy Raines
# 	 	 	 Jim Jones & DJ Crowd
# 	 	 	 Jimi Hendrix & Jim Morrison
# 	 	 	 Jimmy Buffett & Zac Brown Band
# 	 	 	 Jimmy King & King James Versio
# 	 	 	 John Fahey & Peter Lang & Leo Kottke
# 	 	 	 John Scofield & Pat Metheny
# 	 	 	 John Williams & George Duning
# 	 	 	 Johnny Cash & Jerry Lee Lewis & Carl Perkins
# 	 	 	 Johnny Cash & Waylan Jennings
# 	 	 	 Johnny Cash & Waylon Jennings
# 	 	 	 Johnny Cash & Willie Nelson
# 	 	 	 Jorma Kaukonen & Tom Constanten
# 	 	 	 Jose Nunez & Octavina
# 	 	 	 Jr. Walker and The All stars
# 	 	 	 Juice Escobar
# Odd	 (1, 2) 	 Junction (4)
# Odd	 (1, 2) 	 Juneau (2)
# Odd	 (1, 2) 	 Juno (8)
# 	 	 	 K2 & AMK & Haters
# Odd	 (1, 2) 	 Kansas (2)
# 	 	 	 Kanye West & Malik Yusef
# 	 	 	 Kenny G & Michael Bolton & Sade
# Odd	 (1, 2) 	 Kenny G (2)
# 	 	 	 Keyz & Young Money
# Odd	 (1, 2) 	 Kid Dynamite (3)
# Odd	 (1, 2) 	 Korova (2)
# 	 	 	 Kris Kristofferson & Willie Nelson
# 	 	 	 Kristin Banks
# 	 	 	 Kukla & Fran & Ollie
# 	 	 	 La Quela Scaife & Joe Romeo
# 	 	 	 La Quela Scaife & Robert Jason
# 	 	 	 Le Shok And Ink & Dagger
# 	 	 	 Lesser & Rob Crow
# 	 	 	 Lonely Kings & Divit
# 	 	 	 Los Lobos with Barrace Whitfield
# 	 	 	 Lou Reed & John Cale
# 	 	 	 Lou Reed & John Cale & Nico
# 	 	 	 Lou Reed & Metallica
# Near 	 (1, 2) 	 Louis Armstrong & Duke Ellington 		====> Discog Match = Louiis Armstrong & Duke Ellington
# Near 	 (1, 2) 	 Macklemore & Ryan Lewis 		====> Discog Match = Macklemore X Ryan Lewis
# 	 	 	 Macklemore & Ryan Lewis & Wanz
# 	 	 	 Maino & The Mafia
# 	 	 	 Major Lazer & La Roux
# 	 	 	 Makaveli & Dillinger
# 	 	 	 Makoto Kawabata & Richard Youngs
# 	 	 	 Mark Knopfler & Emmylou Harris
# 	 	 	 Mark Mancina & Trevor Rabin
# 	 	 	 Mark O'Connor & Yo-Yo Ma & Edgar Meyer
# 	 	 	 Mars & D.N.A.
# 	 	 	 Marvin Gaye & Diana Ross
# 	 	 	 Marvin Gaye & Kim Weston
# 	 	 	 Marvin Gaye & Mary Wells
# 	 	 	 Marvy Darling
# 	 	 	 Mary Lorson & Saint Low
# 	 	 	 Mary Martin And Noel Coward
# 	 	 	 Matt Skiba & Kevin Seconds
# 	 	 	 Merle Haggard & Willie Nelson
# 	 	 	 Merzbow & Gore Beyond Necropsy
# 	 	 	 Meth & Ghost & Rae
# 	 	 	 Metroschifter & Shipping News
# 	 	 	 MFSB & The Three Degrees
# 	 	 	 Michel Legrand & Miles Davis
# 	 	 	 Micky Finn & "Big" Tiny Little
# 	 	 	 Midnight Highway
# 	 	 	 Mike West & Myshkin
# 	 	 	 Miles Davis & Gil Evans
# 	 	 	 Miles Davis & John Coltrane & Sonny Stitt
# 	 	 	 Mis-teeq
# 	 	 	 Miss Murgatroid & Petra Haden
# Near 	 (3, 2) 	 Mission to Mars 		====> Discog Match = Mission To Mars
# 	 	 	 Mitch Harrell
# 	 	 	 Modest Mouse & 764-Hero
# 	 	 	 Molly McGuire & Iron Rite Mangle
# Near 	 (1, 2) 	 Moon  		====> Discog Match = Moon B
# 	 	 	 More & More & More
# 	 	 	 Morfomen And The Flashbacks
# Odd	 (1, 2) 	 Morgenstern (2)
# Odd	 (1, 2) 	 Morning Dew (2)
# 	 	 	 Mr. Oizo & Gaspard Augé
# Odd	 (1, 2) 	 Murder 1 (2)
# 	 	 	 N.E.R.D.
# 	 	 	 Napalm Death & Coalesce
# 	 	 	 Negativland & Chumbawamba
# 	 	 	 Negru Voda & Third Eye
# Near 	 (1, 2) 	 Neither:Neither World 		====> Discog Match = Neither/Neither World
# 	 	 	 Nels Cline & Devin Sarno
# 	 	 	 Nicky Romero & Calvin Harris
# Odd	 (1, 2) 	 Nile (2)
# Odd	 (1, 2) 	 Nine (3)
# 	 	 	 Nine Inch Nails & David Bowie
# Odd	 (1, 2) 	 Non-Fiction (2)
# Odd	 (1, 2) 	 Norman Blake (2)
# 	 	 	 Nueva era
# Odd	 (1, 2) 	 Oasis (2)
# Odd	 (1, 2) 	 Occult (2)
# 	 	 	 OJ Da Juiceman & Criminal Manne
# Odd	 (1, 2) 	 Olo (8)
# Odd	 (1, 2) 	 Omaha (2)
# Odd	 (1, 2) 	 Omen (3)
# 	 	 	 Operation Ivy & Downfall & Rancid
# 	 	 	 Orbit 3
# 	 	 	 Otis Redding & Carla Thomas
# 	 	 	 Otis Spann & Fleetwood Mac
# Odd	 (1, 2) 	 Out Of Order (12)
# Odd	 (1, 2) 	 Owen (4)
# Odd	 (1, 2) 	 Pain (7)
# Odd	 (1, 2) 	 Park (6)
# 	 	 	 Paul Barrere & Fred Tackett
# 	 	 	 Paul Sawtell & Jerry Goldsmith
# 	 	 	 Paula Abdul & Randy Jackson
# 	 	 	 Peter Case & David Perales
# 	 	 	 Peter Green & Fleetwood Mac
# 	 	 	 Peter Jefferies & Jono Lonie
# 	 	 	 Peter Rowan & Don Edwards
# 	 	 	 Phil Collins & David Crosby
# 	 	 	 Philly Chase
# 	 	 	 Pig & Sow
# 	 	 	 Plug 1 & Plug 2
# 	 	 	 Plus Ones & Travoltas
# Odd	 (1, 2) 	 Poison (3)
# Odd	 (1, 2) 	 Popgun (3)
# Odd	 (1, 2) 	 Porn (2)
# Odd	 (1, 2) 	 Pressure (7)
# 	 	 	 Propellorheads & Shirley Basse
# 	 	 	 Public Enemy & Paris
# 	 	 	 Punkemon
# Odd	 (1, 2) 	 Pure Joy (2)
# Odd	 (1, 2) 	 Pussy Galore (2)
# Odd	 (1, 2) 	 Raffi (2)
# Odd	 (1, 2) 	 Rage (6)
# 	 	 	 Randy Coven & Al Pitrelli & John O. Reilly
# 	 	 	 Rapid Ric
# 	 	 	 Rapid Ric & Bun B
# Odd	 (1, 2) 	 Rasheeda (2)
# Odd	 (1, 2) 	 Raven (6)
# Odd	 (1, 2) 	 Red Letter Day (4)
# Odd	 (1, 2) 	 Red Monkey (2)
# Odd	 (1, 2) 	 Red Planet (2)
# 	 	 	 Rex & Songs: Ohia
# 	 	 	 Richard Youngs & Simon Wickham-Smith
# Odd	 (1, 2) 	 Ricky Nelson (2)
# Odd	 (1, 2) 	 Right Direction (2)
# Odd	 (1, 2) 	 Riot (4)
# 	 	 	 Robbie Williams & Kylie Minogue
# 	 	 	 Robbie Williams & Nicole Kidman
# 	 	 	 Robbie Williams & Pet Shop Boys
# 	 	 	 Robert Miles & Trilok Gurtu
# 	 	 	 Robert Plant & Alison Krauss
# Odd	 (1, 2) 	 Rorschach (2)
# 	 	 	 Royce Lovett
# Near 	 (3, 2) 	 RRAF 		====> Discog Match = RAF
# 	 	 	 Rye Coalition & Karp
# 	 	 	 S.B.O.E.
# Odd	 (1, 2) 	 Sabot (2)
# Odd	 (1, 2) 	 Sarge (2)
# Odd	 (1, 2) 	 Scarface (3)
# 	 	 	 Scott Ritcher & Metroschifter
# Odd	 (1, 2) 	 Scream (2)
# 	 	 	 Screwston
# 	 	 	 Seals and Croft
# 	 	 	 Sebastien Tellier & Mr. Oizo & SebastiAn
# 	 	 	 Shady View Terrace & The Lawrence Arms
# Odd	 (1, 2) 	 Shai (3)
# Odd	 (1, 2) 	 Shallow (2)
# 	 	 	 Shania Twain & Billy Currington
# 	 	 	 Shania Twain & Mark McGrath
# 	 	 	 Shawn Mendes & Camila Cabello
# Odd	 (1, 2) 	 Shelter (2)
# 	 	 	 Shimmer Kids
# 	 	 	 Shiner & Molly McGuire
# Odd	 (1, 2) 	 Shiner (5)
# Odd	 (1, 2) 	 Shutdown (2)
# 	 	 	 Side Arm
# Odd	 (1, 2) 	 Silent Majority (3)
# Odd	 (1, 2) 	 Skirt (3)
# 	 	 	 Sl Jones
# 	 	 	 Sledge Sisters
# 	 	 	 Slight Slappers And Short Hate Temper
# Odd	 (1, 2) 	 Soil (2)
# Odd	 (1, 2) 	 Solstice (2)
# Odd	 (1, 2) 	 Soul Asylum (2)
# Odd	 (1, 2) 	 Spasm (5)
# Odd	 (1, 2) 	 Spite (3)
# 	 	 	 Squeaky Burger
# Odd	 (1, 2) 	 Squealer (2)
# Odd	 (1, 2) 	 Starlet (3)
# 	 	 	 Statik Selektah & JFK
# 	 	 	 Statik Selektah & Lord Sear
# 	 	 	 Stefan Grossman & John Renbourn
# 	 	 	 Stephanie Grappelli & Yehudi Menuhin
# 	 	 	 Steve Dorff & Larry Herbstritt & David Kurtz
# 	 	 	 Steve Earle & The Del McCoury Band
# 	 	 	 Steve Wariner & Nitty Gritty Dirt Band
# Odd	 (1, 2) 	 Steven Wright (2)
# 	 	 	 Stevie Ray Vaughan & Buddy Guy
# Odd	 (1, 2) 	 Stream (3)
# Odd	 (1, 2) 	 Sublime (2)
# Odd	 (1, 2) 	 Supernova (11)
# 	 	 	 Suzanne Langille & Loren Mazzacane Connors
# Odd	 (1, 2) 	 Swing Kids (2)
# 	 	 	 Swizz Beatz & Timbaland
# Odd	 (1, 2) 	 Syrinx (3)
# 	 	 	 T. Lance & The Coctails
# 	 	 	 Tahiti Boy & Mr. Oizo
# 	 	 	 Tahiti Boy & The Palmtree Family
# 	 	 	 Tazzino
# Near 	 (1, 2) 	 Ted Leo : Pharmacists 		====> Discog Match = Ted Leo / Pharmacists
# 	 	 	 Teen Idols & Squirtgun
# Odd	 (1, 2) 	 Telegraph (3)
# 	 	 	 Terror Squad & DJ Khaled
# Odd	 (1, 2) 	 THD (2)
# 	 	 	 The Age Of Love
# Odd	 (1, 2) 	 The Brood (3)
# 	 	 	 The Cannanes & Explosion Robinson
# Odd	 (1, 2) 	 The Clears (2)
# Odd	 (1, 2) 	 The Darts (2)
# 	 	 	 The Dillinger Escape Plan & NORA
# 	 	 	 The Electric Prunes & Peter Lewis
# Odd	 (1, 2) 	 The Fiends (2)
# Odd	 (1, 2) 	 The Frantics (4)
# 	 	 	 The Freeze & The Bollweevils
# Odd	 (1, 2) 	 The Fumes (2)
# Odd	 (1, 2) 	 The Game (2)
# Odd	 (1, 2) 	 The Gits (2)
# 	 	 	 The Intonations
# Odd	 (1, 2) 	 The Invaders (8)
# 	 	 	 The KLF & Tammy Wynette
# 	 	 	 The Lawrence Arms & The Chinkees
# 	 	 	 The Longman
# 	 	 	 The m experience
# 	 	 	 The Mighty Dub Kats
# 	 	 	 The Mighty Mighty Bosstones & Madcap
# 	 	 	 The Movielife & Ex Number Five
# 	 	 	 The Ne'er Do Wells & Judy And The Loadies
# 	 	 	 The Old World
# 	 	 	 The Outcasts & The Arkay IV
# 	 	 	 The Phantom Surfers & Davie Allan
# Odd	 (1, 2) 	 The Quiet Room (2)
# 	 	 	 The Supremes & Four Tops
# 	 	 	 The Telephone Man
# 	 	 	 The Velour Motel
# Odd	 (1, 2) 	 The Vikings (4)
# Odd	 (1, 2) 	 The Weird Lovemakers (2)
# Odd	 (1, 2) 	 The Witches (2)
# Near 	 (1, 2) 	 The World : Inferno Friendship Society 		====> Discog Match = The World / Inferno Friendship Society
# 	 	 	 Timbaland & Katy Perry
# 	 	 	 Toby Bourke & George Michael
# 	 	 	 Tom Fogerty & Randy Oda
# 	 	 	 Tom Waits & Crystal Gayle
# 	 	 	 Tony Hadley & Peter Cox
# 	 	 	 Touchdown & Orthrelm
# 	 	 	 Trap-A-Holics & Hoodrich Pablo Juan & DJ White
# Near 	 (1, 2) 	 Travie Mccoy 		====> Discog Match = Travie McCoy
# 	 	 	 Trenzer
# Odd	 (1, 2) 	 Trouble (5)
# 	 	 	 Trouble Is...
# 	 	 	 TV Tunes
# 	 	 	 Twista & Do Or Die
# 	 	 	 Twista & The Speed Knot Mobsters
# 	 	 	 UB40 & Robert Palmer
# 	 	 	 UK & Whitelabel
# 	 	 	 Unida & Dozer
# 	 	 	 Unrelated Segments & Tidal Waves
# 	 	 	 Usurper II
# 	 	 	 Velton Ray Bunch & Mike Post
# 	 	 	 Walter Daniels & Oblivians & Monsieur Jeffrey Evans
# 	 	 	 Watershed & Hoarse
# 	 	 	 Weather Girls
# 	 	 	 Weird Al Yankovic & Wendy Carlos
# 	 	 	 Whitney Houston & George Michael
# 	 	 	 Wild And Blue
# 	 	 	 Willie Nelson & Waylon Jennings
# 	 	 	 Willie Nelson & Wynton Marsalis
# 	 	 	 Wu-Tang Family
# 	 	 	 Wynton Marsalis & Ellis Marsalis
# 	 	 	 Yelawolf & DJ Paul
# 	 	 	 ZZ Top & Mastodon
# 	 	 	 ≈

# %% [markdown]
# # Known Discog Renames

# %%
from pandas import read_excel
renames = read_excel('/Volumes/Music/Discog/db/DiscogRenames.xlsx')[["Unnamed: 1", "Unnamed: 2"]][1:]
renames.columns = ["My Name", "Discog Name"]
renames

# %%
cutoff=0.8
for discogName in renames["Discog Name"].values:
    cutoffArtists = findNearest(item=discogName, ilist=artists, num=1, cutoff=cutoff)
    print(discogName,'\t',cutoffArtists)

# %%
renames["Discog Name"].values

# %% [markdown]
# # Full Matches

# %%
del saveArtistData["Match"]['11']

# %%
toget = []
for artistName,aData in saveArtistData["Match"].items():
    rename = aData["Rename"]
    discog = aData["Discog"]
    albums = aData["Albums"]
    if discog is not None:
        matches = discog["Name"].values
        for val in matches:
            toget.append(val)
    else:
        continue
        
saveFile(idata=toget, ifile="/Volumes/Music/MusicDB/toget.p")
# Out:
#   --> This file is 69.0kB.

# %%
toget2 = []
for artistName,aData in saveArtistData["Near"].items():
    rename = aData["Rename"]
    discog = aData["Discog"]
    albums = aData["Albums"]
    if discog is not None:
        matches = discog["Name"].values
        for val in matches:
            if val not in toget:
                toget2.append(val)
    else:
        continue
        

for artistName,aData in saveArtistData["Odd"].items():
    rename = aData["Rename"]
    discog = aData["Discog"]
    albums = aData["Albums"]
    if discog is not None:
        matches = discog["Name"].values
        for val in matches:
            if val not in toget:
                toget2.append(val)
    else:
        continue        
        
saveFile(idata=toget2, ifile="/Volumes/Music/MusicDB/toget2.p")
# Out:
#   --> This file is 1.3kB.

# %%
toget3 = []
for i,(artistName,aData) in enumerate(saveArtistData["None"].items()):
    rename = aData["Rename"]
    discog = aData["Discog"]
    albums = aData["Albums"]

    matches = mulArts.getArtistNames(artistName)
    for name,val in matches.items():
        if val is None:
            continue
        if isinstance(val,list):
            for artistID in val:
                toget3.append(artistID)
        else:
            toget3.append(val)
        
toget3 = list(set(toget3))
saveFile(idata=toget3, ifile="/Volumes/Music/MusicDB/toget3.p")
# Out:
# ['4351',
#  '61849',
#  '319628',
#  '79578',
#  '337276',
#  '257115',
#  '1345087',
#  '12551',
#  '260501',
#  '789036',
#  '274516',
#  '543388',
#  '15922',
#  '591648',
#  '512818',
#  '86093',
#  '100756',
#  '132136',
#  '195397',
#  '37909',
#  '208076',
#  '600',
#  '591631',
#  '161808',
#  '18984',
#  '12628',
#  '578944',
#  '30542',
#  '18456',
#  '1046255',
#  '55029',
#  '20172',
#  '130571',
#  '4917',
#  '73037',
#  '3149132',
#  '185582',
#  '4459',
#  '419677',
#  '314566',
#  '101028',
#  '280010',
#  '32990',
#  '178818',
#  '130901',
#  '2343585',
#  '247378',
#  '346294',
#  '21151',
#  '818820',
#  '292538',
#  '846095',
#  '37729',
#  '1269104',
#  '325837',
#  '221614',
#  '1967271',
#  '262943',
#  '363207',
#  '180586',
#  '831769',
#  '2280',
#  '249449',
#  '37071',
#  '5492',
#  '45771',
#  '1484583',
#  '23755',
#  '69021',
#  '38855',
#  '264937',
#  '280794',
#  '1920841',
#  '182738',
#  '191662',
#  '106753',
#  '11614',
#  '612440',
#  '547685',
#  '1253002',
#  '86091',
#  '386155',
#  '1932775',
#  '791',
#  '691469',
#  '2103071',
#  '17966',
#  '269052',
#  '624',
#  '17212',
#  '125431',
#  '229639',
#  '1651851',
#  '76894',
#  '28209',
#  '996625',
#  '103200',
#  '1615988',
#  '304095',
#  '334724',
#  '265629',
#  '13344',
#  '66358',
#  '126659',
#  '121112',
#  '339474',
#  '399398',
#  '84236',
#  '322878',
#  '537320',
#  '2654022',
#  '207136',
#  '5035684',
#  '38661',
#  '7552',
#  '7292',
#  '1303868',
#  '259422',
#  '227919',
#  '103687',
#  '447597',
#  '255674',
#  '480398',
#  '263206',
#  '7118',
#  '79340',
#  '199623',
#  '3452',
#  '40409',
#  '58359',
#  '251877',
#  '160605',
#  '227965',
#  '2184482',
#  '382934',
#  '267395',
#  '1401484',
#  '4778',
#  '42599',
#  '262778',
#  '22533',
#  '654296',
#  '47579',
#  '617226',
#  '308840',
#  '705116',
#  '11213',
#  '505456',
#  '48245',
#  '255408',
#  '292545',
#  '214040',
#  '2341699',
#  '1293332',
#  '468697',
#  '1229555',
#  '23573',
#  '255786',
#  '883097',
#  '53538',
#  '47033',
#  '13608',
#  '38863',
#  '8029',
#  '267997',
#  '42058',
#  '75468',
#  '291699',
#  '2009652',
#  '1548303',
#  '135946',
#  '365456',
#  '254394',
#  '47333',
#  '441660',
#  '443835',
#  '946411',
#  '115177',
#  '356096',
#  '288124',
#  '241513',
#  '315920',
#  '509221',
#  '261324',
#  '44958',
#  '327973',
#  '408497',
#  '5241678',
#  '236897',
#  '54903',
#  '1085638',
#  '499276',
#  '3918',
#  '48077',
#  '1177244',
#  '556963',
#  '789776',
#  '227093',
#  '435032',
#  '833746',
#  '747767',
#  '912972',
#  '4606264',
#  '343201',
#  '43828',
#  '267935',
#  '1415397',
#  '69352',
#  '144927',
#  '959548',
#  '20718',
#  '222578',
#  '229665',
#  '67260',
#  '470081',
#  '302576',
#  '77522',
#  '82294',
#  '76490',
#  '176618',
#  '7640',
#  '67449',
#  '35125',
#  '276264',
#  '271505',
#  '252842',
#  '147031',
#  '232887',
#  '283376',
#  '15885',
#  '259970',
#  '181485',
#  '1057095',
#  '6577769',
#  '1935851',
#  '265409',
#  '1003862',
#  '1830',
#  '971243',
#  '137927',
#  '361998',
#  '651529',
#  '16763',
#  '646603',
#  '255137',
#  '460050',
#  '173279',
#  '1879176',
#  '274736',
#  '1262427',
#  '20182',
#  '264150',
#  '247379',
#  '4720',
#  '123581',
#  '4226580',
#  '1231712',
#  '1248905',
#  '255598',
#  '229194',
#  '92951',
#  '4302933',
#  '239453',
#  '944366',
#  '293634',
#  '910746',
#  '92800',
#  '54650',
#  '333360',
#  '21767',
#  '208267',
#  '227945',
#  '309139',
#  '39776',
#  '215092',
#  '249597',
#  '306505',
#  '760317',
#  '42757',
#  '2222564',
#  '615544',
#  '110593',
#  '120307',
#  '314928',
#  '19731',
#  '59176',
#  '894258',
#  '40029',
#  '687220',
#  '2041566',
#  '2124025',
#  '37734',
#  '55525',
#  '447620',
#  '137880',
#  '20807',
#  '129862',
#  '755046',
#  '275465',
#  '823633',
#  '7710',
#  '423718',
#  '542666',
#  '1019233',
#  '383281',
#  '23302',
#  '745757',
#  '280034',
#  '314926',
#  '59549',
#  '291499',
#  '10263',
#  '679126',
#  '1207395',
#  '350980',
#  '21742',
#  '1866',
#  '25944',
#  '369506',
#  '20185',
#  '135930',
#  '2077383',
#  '191330',
#  '294106',
#  '63202',
#  '254578',
#  '274750',
#  '14013',
#  '669897',
#  '200736',
#  '186262',
#  '2807776',
#  '880644',
#  '1598',
#  '102984',
#  '403351',
#  '6378',
#  '256786',
#  '629791',
#  '217848',
#  '36807',
#  '303763',
#  '56201',
#  '149162',
#  '47742',
#  '1978148',
#  '2896370',
#  '5376',
#  '5772622',
#  '216597',
#  '83609',
#  '344839',
#  '16406',
#  '1474921',
#  '2537',
#  '447473',
#  '257123',
#  '925035',
#  '1425103',
#  '206642',
#  '341573',
#  '52833',
#  '100752',
#  '204817',
#  '57103',
#  '252529',
#  '1351211',
#  '447222',
#  '81013',
#  '173545',
#  '1392650',
#  '187919',
#  '608056',
#  '253392',
#  '137225',
#  '268850',
#  '38767',
#  '561465',
#  '3258778',
#  '337332',
#  '187503',
#  '199766',
#  '3518183',
#  '180356',
#  '3857',
#  '252161',
#  '65712',
#  '109832',
#  '75783',
#  '1905',
#  '390324',
#  '276320',
#  '262399',
#  '18839',
#  '71440',
#  '393192',
#  '8027',
#  '290039',
#  '275193',
#  '613861',
#  '348701',
#  '807530',
#  '16989',
#  '173717',
#  '252467',
#  '24120',
#  '3178',
#  '253307',
#  '12596',
#  '904628',
#  '12927',
#  '50997',
#  '247084',
#  '130060',
#  '131678',
#  '792536',
#  '3310737',
#  '1622988',
#  '773716',
#  '11879',
#  '454965',
#  '634',
#  '274209',
#  '253592',
#  '59792',
#  '17827',
#  '359760',
#  '16261',
#  '269949',
#  '957687',
#  '405595',
#  '87582',
#  '4046897',
#  '3837970',
#  '12821',
#  '21763',
#  '372801',
#  '259799',
#  '271905',
#  '232956',
#  '341732',
#  '1494489',
#  '83242',
#  '631959',
#  '615542',
#  '13456',
#  '9375',
#  '1130400',
#  '417015',
#  '692580',
#  '1965100',
#  '119142',
#  '131372',
#  '11442',
#  '2343584',
#  '17850',
#  '97545',
#  '257768',
#  '431746',
#  '253966',
#  '803809',
#  '19298',
#  '107784',
#  '276145',
#  '1315683',
#  '5249382',
#  '273338',
#  '659671',
#  '36134',
#  '2126398',
#  '223131',
#  '805325',
#  '6295',
#  '308385',
#  '215610',
#  '169457',
#  '303575',
#  '1065010',
#  '108',
#  '193630',
#  '3101',
#  '229116',
#  '177931',
#  '1130374',
#  '253263',
#  '1150806',
#  '12886',
#  '29735',
#  '3071698',
#  '252864',
#  '137418',
#  '133869',
#  '253323',
#  '13451',
#  '108675',
#  '1527592',
#  '14646',
#  '234668',
#  '15330',
#  '59760',
#  '113655',
#  '1169676',
#  '532086',
#  '26801',
#  '644745',
#  '1191825',
#  '17531',
#  '252097',
#  '205682',
#  '75589',
#  '233726',
#  '1025658',
#  '28332',
#  '5682156',
#  '316077',
#  '2010779',
#  '48246',
#  '5731849',
#  '746713',
#  '262950',
#  '350792']

# %%
saveFile(idata=toget3, ifile="/Volumes/Music/MusicDB/toget3.p")
# Out:
#   --> This file is 3.5kB.

# %% [markdown]
# # Mark Soundtracks

# %%
from searchUtils import findDirsPattern, findAll
from fsUtils import moveDir
from fileUtils import getDirBasics
for dirval in findDirsPattern('/Volumes/Music/iTunes Compilation/iTunes Media/Music', pattern="OST"):
    if dirval.endswith("OST"):
        dst = " ".join([dirval[:-3].strip(), "Soundtrack"])
        albumName = " ".join([getDirBasics(dirval)[-1][:-3].strip(), "Soundtrack"])
        for val in findAll(dirval):
            for albumFile in findAll(val):
                m = mp3ID(albumFile)
                m.setAlbum(albumName)
                
        moveDir(dirval, dst)

# %% [markdown]
# # Near Matches

# %%
toExcel = []
for i,(artistName,aData) in enumerate(saveArtistData["Near"].items()):
    print("{0: <3}/{1: <3}".format(i,len(saveArtistData["Near"])), end=" \t")
    rename = aData["Rename"]
    discog = aData["Discog"]
    albums = aData["Albums"]
    if discog is not None:
        matches = discog["Name"].values
        print('{0: <50}'.format(artistName),matches)
    else:
        print('{0: <50}{1: <8}{2}'.format(artistName,'x',len(albums)))
# Out:
# 0  /5   	ACDC                                               ['ACxDC']
# 1  /5   	Macklemore & Ryan Lewis                            ['Macklemore X Ryan Lewis']
# 2  /5   	Michael Jordon                                     ['Michael Jordan (3)' 'Michael Jordan (19)' 'Michael Jordan (5)'
#  'Michael Jordan (13)' 'Michael Jordan (16)' 'Michael Jordan (7)'
#  'Michael Jordan (4)' 'Michael Jordan (17)' 'Michael Jordan (8)'
#  'Michael Jordan (11)' 'Michael Jordan' 'Michael Jordan (10)'
#  'Michael Jordan (9)' 'Michael Jordan (15)' 'Michael Jordan (2)'
#  'Michael Jordan (18)' 'Michael Jordan (14)' 'Michael Jordan (12)'
#  'Michael Jordan (6)']
# 3  /5   	Mission to Mars                                    ['Mission To Mars (3)' 'Mission To Mars (2)' 'Mission To Mars']
# 4  /5   	RRAF                                               ['RAF (2)' 'RAF (5)' 'RAF (21)']

# %% [markdown]
# # Odd Names

# %%
for artistName,aData in saveArtistData["Odd"].items():
    rename = aData["Rename"]
    discog = aData["Discog"]
    albums = aData["Albums"]
    if discog is not None:
        matches = discog["Name"].values
        
        print('{0: <50}'.format(artistName),matches)
    else:
        print('{0: <50}{1: <8}{2}'.format(artistName,'x',len(albums)))
# Out:
# Boris (3)                                          ['Boris (3)']
# Canvas (4)                                         ['Canvas (4)']
# Catastrophic (2)                                   ['Catastrophic (2)']
# Churn (4)                                          ['Churn (4)']
# Co-Ed (2)                                          ['Co-Ed (2)']
# Cranium (4)                                        ['Cranium (4)']
# Cream (2)                                          ['Cream (2)']
# Crisis (8)                                         ['Crisis (8)']
# Diamond Head (2)                                   ['Diamond Head (2)']
# Drunk (2)                                          ['Drunk (2)']
# Electric Wizard (2)                                ['Electric Wizard (2)']
# Emperor (2)                                        ['Emperor (2)']
# Engine (5)                                         ['Engine (5)']
# Ennui (4)                                          ['Ennui (4)']
# Eraserheads (3)                                    ['Eraserheads (3)']
# Eric Thompson (4)                                  ['Eric Thompson (4)']
# Eterne (2)                                         ['Eterne (2)']
# Extreme (2)                                        ['Extreme (2)']
# False Prophets (2)                                 ['False Prophets (2)']
# Fergie (2)                                         ['Fergie (2)']
# Fuel (3)                                           ['Fuel (3)']
# Geraldine (8)                                      ['Geraldine (8)']
# Gnome (2)                                          ['Gnome (2)']
# Grade (2)                                          ['Grade (2)']
# Griffin (3)                                        ['Griffin (3)']
# Guilt (2)                                          ['Guilt (2)']
# Hades (2)                                          ['Hades (2)']
# Harvey Danger (2)                                  ['Harvey Danger (2)']
# Haymarket Riot (2)                                 ['Haymarket Riot (2)']
# Headlock (2)                                       ['Headlock (2)']
# Helium (3)                                         ['Helium (3)']
# Helmet (2)                                         ['Helmet (2)']
# Hem (2)                                            ['Hem (2)']
# Hinder (2)                                         ['Hinder (2)']
# Hole (2)                                           ['Hole (2)']
# Horsey (2)                                         ['Horsey (2)']
# Ikon (4)                                           ['Ikon (4)']
# In Cold Blood (2)                                  ['In Cold Blood (2)']
# Incubus (2)                                        ['Incubus (2)']
# Indecision (2)                                     ['Indecision (2)']
# Inhuman (3)                                        ['Inhuman (3)']
# Integrity (2)                                      ['Integrity (2)']
# Iron Monkey (3)                                    ['Iron Monkey (3)']
# Jackhammer (8)                                     ['Jackhammer (8)']
# James Taylor (2)                                   ['James Taylor (2)']
# Junction (4)                                       ['Junction (4)']
# Juneau (2)                                         ['Juneau (2)']
# Juno (8)                                           ['Juno (8)']
# Kansas (2)                                         ['Kansas (2)']
# Kenny G (2)                                        ['Kenny G (2)']
# Kid Dynamite (3)                                   ['Kid Dynamite (3)']
# Korova (2)                                         ['Korova (2)']
# Morgenstern (2)                                    ['Morgenstern (2)']
# Morning Dew (2)                                    ['Morning Dew (2)']
# Murder 1 (2)                                       ['Murder 1 (2)']
# Nile (2)                                           ['Nile (2)']
# Nine (3)                                           ['Nine (3)']
# Non-Fiction (2)                                    ['Non-Fiction (2)']
# Norman Blake (2)                                   ['Norman Blake (2)']
# Oasis (2)                                          ['Oasis (2)']
# Occult (2)                                         ['Occult (2)']
# Olo (8)                                            ['Olo (8)']
# Omaha (2)                                          ['Omaha (2)']
# Omen (3)                                           ['Omen (3)']
# Out Of Order (12)                                  ['Out Of Order (12)']
# Owen (4)                                           ['Owen (4)']
# Pain (7)                                           ['Pain (7)']
# Park (6)                                           ['Park (6)']
# Poison (3)                                         ['Poison (3)']
# Popgun (3)                                         ['Popgun (3)']
# Porn (2)                                           ['Porn (2)']
# Pressure (7)                                       ['Pressure (7)']
# Pure Joy (2)                                       ['Pure Joy (2)']
# Pussy Galore (2)                                   ['Pussy Galore (2)']
# Raffi (2)                                          ['Raffi (2)']
# Rage (6)                                           ['Rage (6)']
# Rasheeda (2)                                       ['Rasheeda (2)']
# Raven (6)                                          ['Raven (6)']
# Red Letter Day (4)                                 ['Red Letter Day (4)']
# Red Monkey (2)                                     ['Red Monkey (2)']
# Red Planet (2)                                     ['Red Planet (2)']
# Ricky Nelson (2)                                   ['Ricky Nelson (2)']
# Right Direction (2)                                ['Right Direction (2)']
# Riot (4)                                           ['Riot (4)']
# Rorschach (2)                                      ['Rorschach (2)']
# Sabot (2)                                          ['Sabot (2)']
# Sarge (2)                                          ['Sarge (2)']
# Scarface (3)                                       ['Scarface (3)']
# Scream (2)                                         ['Scream (2)']
# Shai (3)                                           ['Shai (3)']
# Shallow (2)                                        ['Shallow (2)']
# Shelter (2)                                        ['Shelter (2)']
# Shiner (5)                                         ['Shiner (5)']
# Shutdown (2)                                       ['Shutdown (2)']
# Silent Majority (3)                                ['Silent Majority (3)']
# Skirt (3)                                          ['Skirt (3)']
# Soil (2)                                           ['Soil (2)']
# Solstice (2)                                       ['Solstice (2)']
# Soul Asylum (2)                                    ['Soul Asylum (2)']
# Spasm (5)                                          ['Spasm (5)']
# Spite (3)                                          ['Spite (3)']
# Squealer (2)                                       ['Squealer (2)']
# Starlet (3)                                        ['Starlet (3)']
# Steven Wright (2)                                  ['Steven Wright (2)']
# Stream (3)                                         ['Stream (3)']
# Sublime (2)                                        ['Sublime (2)']
# Supernova (11)                                     ['Supernova (11)']
# Swing Kids (2)                                     ['Swing Kids (2)']
# Syrinx (3)                                         ['Syrinx (3)']
# Telegraph (3)                                      ['Telegraph (3)']
# THD (2)                                            ['THD (2)']
# The Brood (3)                                      ['The Brood (3)']
# The Clears (2)                                     ['The Clears (2)']
# The Darts (2)                                      ['The Darts (2)']
# The Fiends (2)                                     ['The Fiends (2)']
# The Frantics (4)                                   ['The Frantics (4)']
# The Fumes (2)                                      ['The Fumes (2)']
# The Game (2)                                       ['The Game (2)']
# The Gits (2)                                       ['The Gits (2)']
# The Invaders (8)                                   ['The Invaders (8)']
# The Quiet Room (2)                                 ['The Quiet Room (2)']
# The Vikings (4)                                    ['The Vikings (4)']
# The Weird Lovemakers (2)                           ['The Weird Lovemakers (2)']
# The Witches (2)                                    ['The Witches (2)']
# Trial (5)                                          ['Trial (5)']
# Trouble (5)                                        ['Trouble (5)']
# Tuesday (5)                                        ['Tuesday (5)']
# Tungsten (3)                                       ['Tungsten (3)']
# Twink (4)                                          ['Twink (4)']
# Underdog (2)                                       ['Underdog (2)']
# Vermin (3)                                         ['Vermin (3)']
# Wolfie (3)                                         ['Wolfie (3)']
# Word Salad (2)                                     ['Word Salad (2)']
# YG (2)                                             ['YG (2)']

# %% [markdown]
# # None Match

# %%
## Abwaerts = Abwärts
## Move all ' vs ' into MixTape

## Known
#Beatsnblends
#Dr. Tom Butt

# %%
#artistData['Otis Spann & FM']
albumData["Flo.Rida-Only.One.Flo.Pt.1-(Retail)-2010-NoFS)"]
# Out:
# {'Flo Rida': ['/Volumes/Music/iTunes Consolidate/iTunes Media/Music/Flo Rida/Flo.Rida-Only.One.Flo.Pt.1-(Retail)-2010-NoFS)/1-01 On And On (Prod. by Kevin Rudolf).mp3',
#   '/Volumes/Music/iTunes Consolidate/iTunes Media/Music/Flo Rida/Flo.Rida-Only.One.Flo.Pt.1-(Retail)-2010-NoFS)/1-02 Turn Around (5,4,3,2,1) (Prod. by DJ Frank E; Dada Life, Oligee).mp3',
#   '/Volumes/Music/iTunes Consolidate/iTunes Media/Music/Flo Rida/Flo.Rida-Only.One.Flo.Pt.1-(Retail)-2010-NoFS)/1-03 Come With Me (Prod. by Infinity; Antario TARiO Holmes).mp3',
#   '/Volumes/Music/iTunes Consolidate/iTunes Media/Music/Flo Rida/Flo.Rida-Only.One.Flo.Pt.1-(Retail)-2010-NoFS)/1-04 Who Dat Girl (Prod. by Dr. Luke; Max Martin, Benny Blanco).mp3',
#   '/Volumes/Music/iTunes Consolidate/iTunes Media/Music/Flo Rida/Flo.Rida-Only.One.Flo.Pt.1-(Retail)-2010-NoFS)/1-08 Why You Up In Here (Prod. by KnoBody; Dahound Darien ).mp3',
#   '/Volumes/Music/iTunes Consolidate/iTunes Media/Music/Flo Rida/Flo.Rida-Only.One.Flo.Pt.1-(Retail)-2010-NoFS)/1-09 Puzzle (Prod. by Martin Liedtke & Erik Venhus) (Bonus track).mp3',
#   "/Volumes/Music/iTunes Consolidate/iTunes Media/Music/Flo Rida/Flo.Rida-Only.One.Flo.Pt.1-(Retail)-2010-NoFS)/1-10 Shakin' My Head (Produced by Noel Detail Fisher) (Bonus track).mp3"],
#  'The Saturdays & Flo Rida ': ['/Volumes/Music/iTunes Consolidate/iTunes Media/Music/The Saturdays & Flo Rida /Flo.Rida-Only.One.Flo.Pt.1-(Retail)-2010-NoFS)/1-11 Higher (Remix) (Bonus track).mp3']}

# %% [markdown]
# # Find Matches

# %%
# Out:
# A Flock Of Seagulls
# A Global Threat
# A Great Big World
# A Tribe Called Quest
# A*Teens
# A-Mafia
# A-Set
# A.R. Rahman & The Pussycat Dolls
# A1
# Aaron Neville
# Aaron Neville & Celine Dion
# ABC
# Abdullah
# Abigor
# Abominator
# Above The Law
# Abscess
# Absolution
# Absurdus
# Abwärts
# AC-DC
# Accept
# Ace Of Base
# Acker Bilk
# Action League
# Adam And The Ants
# Adam Ant
# Adam Lambert
# Addis Black Widow
# Addrisi Brothers
# Adele
# Admiral D
# Adryan Russ
# Aerosmith
# AFI
# Afrika Bambaataa & James Brown
# Afrodite
# Aftertaste
# Agent 99
# Agents
# Agnostic Front
# Agua Calientes
# Aimee Mann
# AIR
# Air Supply
# AJR
# Akon
# Aksel Schiøtz
# Al B. Sure!
# Al Bano & Romina Power
# Al Green
# Al Lerner
# Alabama
# Alan Clark
# Alan Jackson
# Alan Licht & Loren Mazzacane Connors
# Alana Davis
# Alanis Morissette
# Alannah Myles
# Albert Ammons
# Albert Collins
# Albert Hammond
# Albert King
# Alberta Cross
# Alberte
# Alex Britti
# Alexia
# Alexia Phillips
# Ali Vegas & L-Gee
# Alice Coltrane & Carlos Santana
# Alice Deejay
# Alice In Chains
# Alicia Keys
# Alien Fashion Show
# Alisha's Attic
# Alison Krauss
# All Chrome
# All Out War
# All Saints
# All-4-One
# Alley Boy
# Aloe Blacc
# Aloha
# Alphaville
# Amanda Marshall
# Amber
# Amber Asylum
# Amel Larrieux
# Amenity
# America
# American Authors
# Amoeba
# Amorphis
# Amsvartner
# Amy Grant
# Amy Rigby
# Amy Winehouse
# Anacrusis
# Anal Cunt
# Anasarca
# Anastacia
# Anata
# Ancient
# And Oceans
# Andre Williams
# Andrea Marcovicci
# Andreas Ammer & F.M. Einheit & Ulrike Haage
# Andreas Johnson
# Andrew Bird
# Andy G And The Roller Kings
# Andy Gibb
# Andy Ling
# Andy M. Stewart
# Angel Beats
# Angel Witch
# Angela Kaset
# Angelic
# Angelina Réaux
# Angelo Moore
# Angie Stone
# Angizia
# Ani DiFranco
# Ani DiFranco & Utah Phillips
# Animaniacs
# Animotion
# Anita Baker
# Anita Ward
# Ann Lee
# Anna Nalick
# Anne Dorte Michelsen
# Anne Linnet
# Anne Murray
# Anne Sofie Von Otter & Elvis Costello
# Annie Lennox
# Anonymous 4
# Anorexia Nervosa
# Another Level
# Another Nothing
# Anouk
# Antaeus
# Anthony Moore
# Anthrax
# Anti-Flag
# Antichrisis
# Antiloop
# Antique
# Antonio Testa & Alio Die
# Anvil
# Aphex Twin
# Apollo 440
# Apoptygma Berzerk
# Apothys
# Arcade Fire
# Arckanum
# Arctic Monkeys
# Arcturus
# Area 54
# Area 7
# Aretha Franklin
# Ariana Grande
# Arkham 13
# Arma Angelus
# Armand Van Helden
# Armin van Buuren
# Armored Saint
# Arp
# Arrested Development
# Art Garfunkel
# Art Tatum
# Artful Dodger
# Arthur Lyman
# Articles Of Faith
# Artie Shaw
# As All Die
# As Friends Rust
# Ashanti
# Ashes
# Ashes You Leave
# Ashley Tisdale
# Ashtrayhead
# Asia
# Asleep At The Wheel
# Aspera Ad Astra
# Assemblage 23
# Assert
# Assück
# Astral Projection
# Astroline
# Astroqueen
# Astrud Gilberto
# At The Drive-In
# At The Gates
# ATB
# ATC
# Athenaeum
# Ativin
# Atlantic Ocean
# Atlantic Starr
# Atlantis Ita
# Atomic Kitten
# Atomic Opera
# Atrax Morgue
# Atreyu
# Atrox
# Audio Science
# Aura
# Aurora
# Autograph
# Autonomy
# Avant
# Avenger
# Average White Band
# Avernus
# Avicii
# Avril Lavigne
# Avskum
# Ayahuasca
# Ayla

# %%
from searchUtils import findNearest

class multiArtist:
    def __init__(self, cutoff=0.9, discdata=None, exact=False):
        self.cutoff   = cutoff    
        self.discdata = discdata
        self.exact    = exact
        
        self.basicdelims = ["Duet With", "Presents", "Featuring"]
        self.delims = [",", "&", " And ", "+", "/", "With The", " with ", " With ", " y ", " Y ", " feat.",  " ft.", " Feat. ", " x ", " X "]
        self.discArtists = []
        if self.discdata is not None:
            self.discArtists = [x for x in discdata.keys() if x is not None]
        self.knownDelimArtists = {artist: True for artist in self.discArtists if self.nDelims(artist) > 0}

    
    def getDiscArtists(self):
        return self.discArtists
    
    def getKnownDelimArtists(self):
        return self.knownDelimArtists  
    
    def isKnownArtist(self, artist):
        if isinstance(self.discdata, dict):
            return self.discdata.get(artist) != None
        return False
    
    def nDelims(self, artist):
        return sum([x in artist for x in self.delims])
    
    
    def joinNames(self, delim, names):
        joinVal = delim
        if delim.startswith(" ") is False:
            joinVal = " {0}".format(joinVal)
        if delim.endswith(" ") is False:
            joinVal = "{0} ".format(joinVal)
        
        return joinVal.join(names)
    
    
    def getDelimData(self, val, debug=False):
        valdata = {d: [x.strip() for x in val.split(d)] for d in self.delims if d in val}
        if debug:
            print("\tDelimParsing ==> {0}".format(valdata))
        for k,v in valdata.items():
            if len(v) == 3:
                v.append(self.joinNames(delim=k, names=v[:2]))
                v.append(self.joinNames(delim=k, names=v[1:-1]))
        if debug:
            print("\tDelimParsing ==> {0}".format(valdata))

        return valdata
    
    
    def getBasicDelimData(self, val):
        valdata = {d: [x.strip() for x in val.split(d)] for d in self.basicdelims if d in val}
        return valdata

    def getNdelims(self, val):
        return len(val)

    def addArtist(self, allArtists, val, debug=False):
        #print("L={0}".format(len(allArtists)))
        if allArtists.get(val) is None:
            if debug:
                print("Adding {0}. Sum is {1}".format(val, len(allArtists)))
            allArtists[val] = True
    
    
    def cleanArtist(self, artist):
        artist = artist.replace("(", "")
        artist = artist.replace(")", "")
        return artist


    def newMethod(self, artist, debug=False):
        if debug is True:
            print("Parsing [{0}]".format(artist))
        artist = self.cleanArtist(artist)
        allArtists = {}
        d1delims = self.getBasicDelimData(artist)
        if len(d1delims) == 0:
            d1delims = self.getDelimData(artist)
        if debug:
            print('1','\t',artist,'===>',d1delims)

        knownArtists = set()
        if len(d1delims) == 0:
            self.addArtist(allArtists, artist, debug)
            knownArtists = set(allArtists.keys())
        elif self.isKnownArtist(artist):
            self.addArtist(allArtists, artist, debug)
            knownArtists = set(allArtists.keys())
            d1delims = {}


        ##############################################################################
        ## 1st Delimiter Split
        ##############################################################################
        for delim1, delimdata1 in d1delims.items():
            delimdata1 = list(set(delimdata1).difference(knownArtists))
            for artist1 in delimdata1:
                d2delims = self.getDelimData(artist1)
                if debug:
                    print('2','\t',artist1,'===>',d2delims)
                if self.getNdelims(d2delims) == 0:
                    self.addArtist(allArtists, artist1, debug)
                    knownArtists = set(allArtists.keys())
                    continue
                elif self.isKnownArtist(artist1):
                    self.addArtist(allArtists, artist1, debug)
                    knownArtists = set(allArtists.keys())
                    d2delims = {}

                    
                ##############################################################################
                ## 2nd Delimiter Split
                ##############################################################################
                for delim2, delimdata2 in d2delims.items():
                    delimdata2 = list(set(delimdata2).difference(knownArtists))
                    for artist2 in delimdata2:
                        d3delims = self.getDelimData(artist2)
                        if debug:
                            print('3','\t',artist2,'===>',d3delims)
                        if self.getNdelims(d3delims) == 0:
                            self.addArtist(allArtists, artist2)
                            knownArtists = set(allArtists.keys())
                            continue
                        elif self.isKnownArtist(artist2):
                            self.addArtist(allArtists, artist2)
                            knownArtists = set(allArtists.keys())
                            d3delims = {}

                            
                        ##############################################################################
                        ## 3rd Delimiter Split
                        ##############################################################################
                        for delim3, delimdata3 in d3delims.items():
                            delimdata3 = list(set(delimdata3).difference(knownArtists))
                            for artist3 in delimdata3:
                                d4delims = self.getDelimData(artist3)
                                if self.getNdelims(d4delims) == 0:
                                    self.addArtist(allArtists, artist3)
                                    knownArtists = set(allArtists.keys())
                                    continue
                                elif self.isKnownArtist(artist3):
                                    self.addArtist(allArtists, artist3)
                                    knownArtists = set(allArtists.keys())
                                    d4delims = {}
                                    

                                ##############################################################################
                                ## 4th Delimiter Split
                                ##############################################################################
                                for delim4, delimdata4 in d4delims.items():
                                    delimdata4 = list(set(delimdata4).difference(knownArtists))
                                    for artist4 in delimdata4:
                                        d5delims = self.getDelimData(artist4)
                                        if self.getNdelims(d5delims) == 0:
                                            self.addArtist(allArtists, artist4)
                                            knownArtists = set(allArtists.keys())
                                            continue
                                        elif self.isKnownArtist(artist4):
                                            self.addArtist(allArtists, artist4)
                                            knownArtists = set(allArtists.keys())
                                            d5delims = {}


                                        ##############################################################################
                                        ## 5th Delimiter Split
                                        ##############################################################################
                                        for delim5, delimdata5 in d5delims.items():
                                            delimdata5 = list(set(delimdata5).difference(knownArtists))
                                            for artist5 in delimdata5:
                                                d6delims = self.getDelimData(artist5)
                                                if self.getNdelims(d6delims) == 0:
                                                    self.addArtist(allArtists, artist5)
                                                    knownArtists = set(allArtists.keys())
                                                    continue
                                                elif self.isKnownArtist(artist5):
                                                    self.addArtist(allArtists, artist5)
                                                    knownArtists = set(allArtists.keys())
                                                    d6delims = {}

                                                    

        ##############################################################################
        ## Combine Results
        ##############################################################################                                                    
        results = {}
        if self.discdata is not None and len(self.discArtists) > 0:
            for name in knownArtists:
                retval = self.discdata.get(name)
                if self.exact is False:
                    if retval is None:
                        retval = findNearest(name, self.discArtists, 1, self.cutoff)
                        if len(retval) == 1:
                            retval = self.discdata.get(retval[0])
                        else:
                            retval = None
                        
                results[name] = retval
        else:
            results = {k: ['?'] for k,v in allArtists.items()}
                
        return results

    def getArtistNames(self, artist, debug=False):        
        return self.newMethod(artist, debug)
    
    
    
        if self.nDelims(artist) == 0:
            names = {artist: []}
            return names
        
        if self.discdata is not None and len(self.discArtists) > 0:
            retval = self.discdata.get(artist)
            if retval is not None:
                return {artist: retval}
            else:
                retval = findNearest(artist, self.discArtists, 1, self.cutoff)
                if len(retval) == 1:
                    return {artist: self.discdata.get(retval[0])}        
        
        names = {artist: None}
        names = self.splitArtist(names)
        names = self.unravelDict(names)
        names = self.unravelDict(names)
        return names


    def unravelDict(self, dvals):
        fvals = {}
        for k,v in dvals.items():
            if isinstance(v, dict):
                for k2,v2 in v.items():
                    if isinstance(v2, dict):
                        for k3,v3 in v.items():
                            if isinstance(v3, dict):
                                for k4,v4 in v.items():
                                    fvals[k4] = v4
                            else:
                                fvals[k3] = v3
                    else:
                        fvals[k2] = v2
            else:
                fvals[k] = v

        return fvals


    def splitArtistDelim(self, artist, delval):
        names = {}    
        if delval not in artist:
            return None

        for val in artist.split(delval):
            val = val.strip()
            
            if self.discdata is not None and len(self.discArtists) > 0:
                retval = self.discdata.get(val)
                if retval is not None:
                    names[val] = retval
                else:
                    retval = findNearest(val, self.discArtists, 1, self.cutoff)
                    if len(retval) == 0:
                        names[val] = None
                    else:
                        names[val] = retval
            else:
                names[val] = [-1]

        if len(names) == 0:
            return None

        if any(names.values()) is False:
            return None

        return names


    def splitArtist(self, result):
        delims = self.delims
            
        #print("Input: {0}".format(result))
        for name in result.keys():
            #print("  Name -->",name,"\tCurrent Value -->",result[name])
            if result[name] is None:
                for delim in delims:
                    #print("\tDelim: {0}  for {1}".format(delim, name))
                    result2 = self.splitArtistDelim(name,delval=delim)
                    #print("\tDelim Result: {0}".format(result2))


                    if result2 is not None:
                        result[name] = result2
                        #print("\tName:",name,'\tResult:',result2)
                        for name2 in result2.keys():
                            if result2[name2] is None:
                                for delim2 in delims:
                                    #print("\t\tDelim2: {0}  for {1}".format(delim2, name2))
                                    result3 = self.splitArtistDelim(name2,delval=delim2)
                                    #print("\t\tDelim Result: {0}".format(result3))


                                    if result3 is not None:
                                        #print("\t\tName:",name2,'\tResult:',result3)
                                        result2[name2] = result3

                                        ## Breaking from delim2 
                                        break

                        ## Breaking from delim
                        break

        return result

# %%
#artistDB = disc.getArtistNameToIDData()
artistNameToID = {}
for artistID, artistName in discdf["Artist"].to_dict().items():
    if artistNameToID.get(artistName) is None:
        artistNameToID[artistName] = []
    artistNameToID[artistName].append(artistID)

# %%
for i,(artistName,aData) in enumerate(saveArtistData["None"].items()):
    rename = aData["Rename"]
    discog = aData["Discog"]
    albums = aData["Albums"]

    matches = mulArts.getArtistNames(artistName)
    if all(matches.values()):
        for albumName,albumValueData in albums.items():
            if len(albumValueData) == 1:
                print('{0: <50}'.format(artistName),matches)
                print("\t{0}\t{1}\n".format(len(albumValueData), albumName))
# Out:
# A.R. Rahman & The Pussycat Dolls                   {'The Pussycat Dolls': ['308385'], 'A.R. Rahman': ['4459']}
# 	1	Jai Ho! (You Are My Destiny)
#
# Belle & Sebastian & Norah Jones                    {'Sebastian': ['2560410', '1426814', '1762314', '2558416', '317020', '1874826', '1080828', '250428', '188432', '2598235', '1827936', '1095737', '715637', '2379541', '2568243', '642246', '3130549', '3891949', '61849', '2253450', '1782951', '533654', '3227158', '1278360', '5116260', '2112462', '1684564', '1195267', '4907576', '338281', '3171482', '3150783', '109984', '2039485', '927890', '3085595'], 'Belle & Sebastian': ['252864'], 'Belle': ['852610', '782245', '271905'], 'Norah Jones': ['147031']}
# 	1	Featuring
#
# Brian Eno & David Byrne                            {'David Byrne': ['3918'], 'Brian Eno': ['634']}
# 	1	My Life In The Bush Of Ghosts
#
# Buddy Guy & Jonny Lang                             {'Buddy Guy': ['259799'], 'Jonny Lang': ['343201']}
# 	1	Random
#
# David Archuleta & David Cook                       {'David Cook': ['4695701', '4411112', '1782817', '2131530', '1283139', '1924688', '393192'], 'David Archuleta': ['1425103']}
# 	1	Random
#
# DJ Snake & Lil' Jon                                {'DJ Snake': ['4505015', '4011416', '7118', '3277528', '579573', '3441484', '426896'], "Lil' Jon": ['120307']}
# 	1	Turn Down For What
#
# Dolla & T-Pain & Akon                              {'Dolla': ['904628', '3436604', '1990851', '1539607', '4375786'], 'Akon': ['229665'], 'T-Pain': ['382934', '5554472']}
# 	1	Random
#
# Don Henley & Patty Smith                           {'Don Henley': ['249597'], 'Patty Smith': ['669897']}
# 	1	Random
#
# Donell Jones & Left Eye                            {'Left Eye': ['276264'], 'Donell Jones': ['38855']}
# 	1	Random
#
# George Michael & Mary J. Blige                     {'George Michael': ['32990'], 'Mary J. Blige': ['4778']}
# 	1	As Single Cd
#
# Gorillaz & D12                                     {'Gorillaz': ['6378'], 'D12': ['204817']}
# 	1	911
#
# Hitch Hiker & Dumont                               {'Hitch Hiker': ['20807'], 'Dumont': ['327973']}
# 	1	2nd dimension
#
# Jessie J, Ariana Grande & Nicki Minaj              {'Jessie J': ['2126398'], 'Ariana Grande': ['3310737'], 'Nicki Minaj': ['1615988']}
# 	1	Bang Bang - Single
#
# Jestofunk & Cinda                                  {'Cinda': ['131678'], 'Jestofunk': ['7640']}
# 	1	Random
#
# Johnny Cash & Waylon Jennings                      {'Waylon Jennings': ['263206'], 'Johnny Cash': ['730612', '135946']}
# 	1	Heroes
#
# Kenny G & Michael Bolton & Sade                    {'Kenny G': ['96114', '37734', '2607704', '1541475'], 'Sade': ['19731'], 'Michael Bolton': ['274209']}
# 	1	Random
#
# Macklemore & Ryan Lewis & Wanz                     {'Wanz': ['273338', '2761558'], 'Macklemore': ['792536'], 'Ryan Lewis': ['803809']}
# 	1	Thrift Shop
#
# MFSB & The Three Degrees                           {'MFSB': ['3452'], 'The Three Degrees': ['36807']}
# 	1	Super Disco Hits
#
# More & More & More                                 {'More': ['471029', '414451', '13456', '95684']}
# 	1	Random
#
# Nicky Romero & Calvin Harris                       {'Nicky Romero': ['1229555'], 'Calvin Harris': ['1114466', '3516469', '431673', '222578']}
# 	1	Iron (Single)
#
# Shania Twain & Billy Currington                    {'Shania Twain': ['130060'], 'Billy Currington': ['390324']}
# 	1	Party For Two
#
# Shania Twain & Mark McGrath                        {'Mark McGrath': ['1421267', '280794', '4241898'], 'Shania Twain': ['130060']}
# 	1	Party For Two
#
# Shawn Mendes & Camila Cabello                      {'Shawn Mendes': ['4046897'], 'Camila Cabello': ['3518183']}
# 	1	I Know What You Did Last Summer
#
# Stephanie Grappelli & Yehudi Menuhin               {'Yehudi Menuhin': ['532086'], 'Stephanie Grappelli': ['5731849']}
# 	1	Jalousie
#
# Steve Wariner & Nitty Gritty Dirt Band             {'Steve Wariner': ['692580'], 'Nitty Gritty Dirt Band': ['178818']}
# 	1	Miscellaneous Live Recordings
#
# The KLF & Tammy Wynette                            {'Tammy Wynette': ['16406'], 'The KLF': ['2666675', '3178']}
# 	1	Random
#
# UK & Whitelabel                                    {'Whitelabel': ['4440510', '1269104', '4606498'], 'UK': ['69352', '414471']}
# 	1	Silencio - Vinyl

# %%
#discdf[discdf.index == '730612']
discdf[discdf.index == '135946']
# Out:
#                                Ref         Name  Known  \
# 135946  /artist/135946-Johnny-Cash  Johnny Cash   True
#
#                                               Artists  \
# 135946  [Johnny Cash, Jerry Lee Lewis, Willie Nelson]
#
#                                         Genre                      Style  \
# 135946  [Folk, World, & Country, Rock, Blues]  [Country, , Country Rock]
#
#              Artist  Artist Num
# 135946  Johnny Cash         NaN

# %%
for artistName,aData in saveArtistData["None"].items():
    rename = aData["Rename"]
    discog = aData["Discog"]
    albums = aData["Albums"]

    matches = mulArts.getArtistNames(artistName)
    if not all(matches.values()):
        print('{0: <50}'.format(artistName),matches)
# Out:
# Duke Ellington with the Ron Collier Orchestra      {'Duke Ellington': ['145257'], 'the Ron Collier Orchestra': None}

# %%
x = artistNames[4]
items = artistNames
my_str_as_bytes = str.encode(x, 'utf-8')
print(my_str_as_bytes,type(my_str_as_bytes)) # ensure it is byte representation


from unicodedata import normalize
keys = ['NFC', 'NFKC', 'NFD', 'NFKD']
for key in keys:
    print(x,'<---',key)    
    print(findNearest(item=x, ilist=items, num=1, cutoff=1.0))
    my_str = normalize(key, x)
    print(findNearest(item=my_str, ilist=items, num=1, cutoff=1.0))
    print(my_str,type(my_str))
    my_str_as_bytes = str.encode(my_str, 'utf-8')
    print(my_str_as_bytes,type(my_str_as_bytes)) # ensure it is byte representation
    my_decoded_str = my_str_as_bytes.decode()
    print(my_decoded_str,type(my_decoded_str)) # ensure it is string representation
    print(findNearest(item=my_decoded_str, ilist=items, num=1, cutoff=1.0))
    print("")

# %% [markdown]
# # Test

# %%
ifile = "/Volumes/Music/iTunes MixTape/iTunes Media/Music/24 Shots/01 Intro (Power Of The Dollar).mp3"
isFile(ifile)

# %%
x = artistNames[4]
x = 'Henryk Górecki'


items = artistNames

from unicodedata import normalize
keys = ['NFC', 'NFKC', 'NFD', 'NFKD']
for key in keys:
    print(x,'<---',key)    
    print(findNearest(item=x, ilist=items, num=1, cutoff=1.0))
    my_str = normalize(key, x)
    print(findNearest(item=my_str, ilist=items, num=1, cutoff=1.0))
    print(my_str,type(my_str))
    my_str_as_bytes = str.encode(my_str, 'utf-8')
    print(my_str_as_bytes,type(my_str_as_bytes)) # ensure it is byte representation
    my_decoded_str = my_str_as_bytes.decode()
    print(my_decoded_str,type(my_decoded_str)) # ensure it is string representation
    print(findNearest(item=my_decoded_str, ilist=items, num=1, cutoff=1.0))
    print("")

# %%
m = mp3ID(ifile)
m.getInfo()

# %%
pb  = pathBasics(debug=False)
pbc = pb.getPaths(ifile)
pbc.getDict()

# %%
from mp3id import mp3ID
mp3Vals = {}
for artistName,aData in saveArtistData['Odd'].items():
    print(artistName)
    discog = aData['Discog']
    artist = None
    if isinstance(discog, DataFrame):
        if discog.shape[0] == 1:
            artist = discog['Artist'][0] #.values
            
    if artist is None:
        continue
        
    for album,albumFiles in aData['Albums'].items():
        print('  ',album)
        for albumFile in albumFiles:
            print('\t',albumFile)
            m = mp3ID(albumFile)
            mArtist = m.getArtist()[0]
            if mArtist == artistName:
                print("\t\tArtist: {0} <--> {1}".format(mArtist,artist))
                m.setArtist(artist)

            mAlbumArtist = m.getAlbumArtist()[0]
            if mAlbumArtist == artistName:
                print("\t\tAlbumArtist: {0} <--> {1}".format(mAlbumArtist,artist))
                m.setAlbumArtist(artist)
            #mp3Vals[albumFile] = mid.getInfo()

# %%
mp3Vals

# %% [markdown]
# # Multi Artists

# %%
artistDB = disc.getArtistIDToNameData()
artistNameToID = {v: k for k,v in artistDB.items()}
mulArts  = multiArtist(cutoff=0.9, discdata=artistNameToID, exact=False)
# Out:
# Loading data from /Volumes/Music/Discog/db/ArtistIDToName.p
#   --> This file is 10.3MB.
# Loading /Volumes/Music/Discog/db/ArtistIDToName.p

# %%
#len(artistDB)
len(artistNameToID)
# Out:
# 544416

# %%
renameReplacements

# %%
findNearest(item="Andre Previn", ilist=artistDB.keys(), num=10, cutoff=0.7)

# %%
x = "Céline Dion"

from unicodedata import normalize
keys = ['NFC', 'NFKC', 'NFD', 'NFKD']
for key in keys:
    continue
    print(x,'<---',key)    
    print(findNearest(item=x, ilist=items, num=1, cutoff=1.0))
    my_str = normalize(key, x)
    print(findNearest(item=my_str, ilist=items, num=1, cutoff=1.0))
    print(my_str,type(my_str))
    my_str_as_bytes = str.encode(my_str, 'utf-8')
    print(my_str_as_bytes,type(my_str_as_bytes)) # ensure it is byte representation
    my_decoded_str = my_str_as_bytes.decode()
    print(my_decoded_str,type(my_decoded_str)) # ensure it is string representation
    print(findNearest(item=my_decoded_str, ilist=items, num=1, cutoff=1.0))
    print("")

# %%
for artistName,artistData in saveArtistData.items():
    found = artistData[0]
    if found is False:
        retval = ma.getArtistNames(artistName)
        if len(retval) > 1:
            artistNames = [k for k,v in retval.items() if v is not None]
            print("{0: <50}{1}".format(artistName,artistNames))
        else:
            print("{0: <50}{1}".format(artistName,artistData[0]))

# %%
lvals = list(discdf["Artist"])
test  = "*NSYNC"
from searchUtils import findNearest
findNearest(item=test, ilist=lvals, num=1, cutoff=0.9)

# %%
def getMusicData(artist):
    retval = musicdf[musicdf["Artist"] == artist]
    if retval.shape[0] > 0:
        return retval
    else:
        return None

# %%
artistIDtoName = disc.getArtistIDToNameData()
artistIDtoRefs  = disc.getArtistIDToRefData()
albumIDtoName = disc.getAlbumIDToNameData()
albumIDtoRef   = disc.getAlbumIDToRefData()

artistIDtoAlbumNames = disc.getArtistIDAlbumNames()
artistIDtoAlbumIDs = disc.getArtistIDAlbumIDs()

artistMetaData = disc.getAlbumArtistMetaData()

# %%
colArtistIDtoName = disc.getCollectionIDToNameData()
colArtistIDtoRefs = disc.getCollectionIDToRefData()
colArtistReftoCnts = disc.getCollectionRefCountsData()

artistIDtoName = disc.getArtistIDToNameData()
artistIDtoRefs  = disc.getArtistIDToRefData()
albumIDtoName = disc.getAlbumIDToNameData()
albumIDtoRef   = disc.getAlbumIDToRefData()

artistIDtoAlbumNames = disc.getArtistIDAlbumNames()
artistIDtoAlbumIDs = disc.getArtistIDAlbumIDs()

artistMetaData = disc.getAlbumArtistMetaData()



def splitMetaData(x):
    retval = {}
    if isinstance(x, dict):
        for k,v in x.items():
            retval[k] = [z[0] for z in v.most_common(3)]
    else:
        retval = None
    return retval

from pandas import Series, DataFrame
sArtistToRef  = Series(artistIDtoRefs)
sArtistToName = Series(artistIDtoName)
sAlbumToRef   = Series(albumIDtoRef)
sAlbumToName  = Series(albumIDtoName)

sArtistToAlbums = Series(artistIDtoAlbumIDs)
sArtistToAlbumNames = Series(artistIDtoAlbumNames)
sArtistAlbums = Series([dict(zip(x, y)) for x,y in list(zip(sArtistToAlbums.values, sArtistToAlbumNames))], index=sArtistToAlbums.index)

sArtistMetaData = Series(artistMetaData)
sArtistMetaData = sArtistMetaData.apply(splitMetaData)


cols = ["Ref"]
discdf = DataFrame(sArtistToRef)
discdf.columns = cols
discdf = discdf.join(DataFrame(sArtistToName))
cols += ["Name"]
discdf.columns = cols
tmp = DataFrame(DataFrame(sArtistMetaData)[0].tolist())
tmp.index = sArtistMetaData.index
discdf = discdf.join(tmp)
cols += ["Extra Artists", "Genres", "Styles"]
discdf.columns = cols
discdf = discdf.join(DataFrame(sArtistAlbums))
cols += ["Albums"]
discdf.columns = cols




sColArtistToRef  = Series(colArtistIDtoRefs)
sColArtistToName = Series(colArtistIDtoName)
sColArtistRefToCnts = Series(colArtistReftoCnts)

cols = ["Ref"]
coldiscdf = DataFrame(sColArtistToRef)
coldiscdf.columns = cols
coldiscdf = coldiscdf.join(DataFrame(sColArtistToName))
cols += ["Name"]
coldiscdf.columns = cols

colrefdf = DataFrame(sColArtistRefToCnts)
colrefdf.columns = ["Counts"]
colrefdf.reset_index(inplace=True)
colrefdf.columns = ["Ref", "Counts"]
coldiscdf = coldiscdf.merge(colrefdf, on="Ref")
coldiscdf.index = DataFrame(sColArtistToRef).index

coldiscdf = coldiscdf.merge(discdf, on=["Ref", "Name"], how='left')
coldiscdf.index = DataFrame(sColArtistToRef).index

# %%
sColArtistToRef  = Series(colArtistIDtoRefs)
sColArtistToName = Series(colArtistIDtoName)
sColArtistRefToCnts = Series(colArtistReftoCnts)

cols = ["Ref"]
coldiscdf = DataFrame(sColArtistToRef)
coldiscdf.columns = cols
coldiscdf = coldiscdf.join(DataFrame(sColArtistToName))
cols += ["Name"]
coldiscdf.columns = cols

colrefdf = DataFrame(sColArtistRefToCnts)
colrefdf.columns = ["Counts"]
colrefdf.reset_index(inplace=True)
colrefdf.columns = ["Ref", "Counts"]
coldiscdf = coldiscdf.merge(colrefdf, on="Ref")
coldiscdf.index = DataFrame(sColArtistToRef).index

coldiscdf = coldiscdf.merge(discdf, on=["Ref", "Name"], how='left')
coldiscdf.index = DataFrame(sColArtistToRef).index

# %%
coldiscdf.to_pickle("ArtistDiscog.p")

# %%
coldiscdf[coldiscdf["Name"] == "Dave Matthews"]

# %%
colrefdf

# %%
coldiscdf.shape

# %%
coldiscdf.merge(colrefdf, on="Ref", how="left")

# %%
coldiscdf.merge(sColArtistRefToCnts, on="")

# %%
discdf.shape

# %%
sArtistToAlbums     = Series(artistIDtoAlbumIDs)
sArtistToAlbumNames = Series(artistIDtoAlbumNames)

# %%
s = Series([dict(zip(x, y)) for x,y in list(zip(sArtistToAlbums.values, sArtistToAlbumNames))], index=sArtistToAlbums.index)

# %%
s

# %%
fixes = {}
iDir  = None
debug = False
for ifile,iPathData in jzpathdata.items():
    iTagData = jztagdata[ifile]
    
    pathArtist = iPathData['pbArtist']
    
    maPathArtists     = ma.getArtistNames(pathArtist)
    maTagArtists      = ma.getArtistNames(iTagData['Artist'])
    maTagAlbumArtists = ma.getArtistNames(iTagData['AlbumArtist'])

    if maTagArtists == maTagAlbumArtists:
        if maTagAlbumArtists == maPathArtists:
            continue
            print("Looks good")
        else:
            if debug:
                print("\nDifferent Artists:")
                print("\tPath:  {0}".format(maPathArtists.keys()))
                print("\tTag:   {0}".format(maTagArtists.keys()))
                print("\tTagAA: {0}".format(maTagAlbumArtists.keys()))
            if iDir is None:
                iDir = ifile.split(pathArtist)[0]                
                fixes[iDir] = {}
                print("  Adding {0}".format(iDir))
            if fixes[iDir].get(pathArtist) is None:
                fixes[iDir][pathArtist] = {}
                print("\tAdding {0}".format(pathArtist))
            iData = ifile.split(pathArtist)[1][1:]
            fixes[iDir][pathArtist][iData] = {"Error": "Path", "Path": maPathArtists, "Artist": maTagArtists, "AlbumArtist": maTagAlbumArtists}
            print("\t  Adding {0}".format(iData))
    else:
        if debug:
            print("\nUnknown Artist to Discogs:")
            print("\tPath:  {0}".format(maPathArtists))
            print("\tTag:   {0}".format(maTagArtists))
            print("\tTagAA: {0}".format(maTagAlbumArtists))


        if iDir is None:
            iDir = ifile.split(pathArtist)[0]                
            fixes[iDir] = {}
            print("  Adding {0}".format(iDir))
        if fixes[iDir].get(pathArtist) is None:
            fixes[iDir][pathArtist] = {}
            print("\tAdding {0}".format(pathArtist))
        iData = ifile.split(pathArtist)[1][1:]
        fixes[iDir][pathArtist][iData] = {"Error": "Tag", "Path": maPathArtists, "Artist": maTagArtists, "AlbumArtist": maTagAlbumArtists}
        print("\t  Adding {0}".format(iData))

# %%
saveFile(idata=fixes, ifile="fixes.yaml")

# %%
disc = discogs()
bsdata = searchDiscogs("Duke Ellington with the Ron Collier Orchestra Collages", requireUS=True, release=True)

# %%
from webUtils import getHTML
from artist import artist
#bsdata = getHTML(bsdata)

# %%
h4s = bsdata.findAll("h4")
h5s = bsdata.findAll("h5")



for ih4,h4 in enumerate(h4s):
    print(h4)
    spans = h4.findAll("span")
    ref   = None
    if len(spans) == 0:
        ref = h4.find("a")
    else:
        ref = spans[0].find("a")

    if ref is None:
        continue

    try:
        href   = ref.attrs.get('href')
        name   = ref.text.strip()
    except:
        print("Could not get name/href from {0}".format(ref))
        continue

# %%
ah5s

# %%
artistData

# %%
albumData  = [x for x in h4s if len(x.findAll('a')) > 0]
albumData  = [x.findAll('a') for x in albumData if not x.find('a').attrs['href'].startswith("/sell/")]

artistData = [x.findAll("a") for x in h5s if len(x.findAll('span')) > 0]
#artistData = [x.findAll("a") for x in artistData]

# %%
                    baseURL = disc.discogURL
                    url = urllib.parse.urljoin(baseURL, href)
                    self.downloadAlbumURL(url, savename)

# %%
def getRefName(ref):
    try:
        href   = ref.attrs.get('href')
        name   = ref.text.strip()
    except:
        href   = None
        name   = None
        
    return href,name

# %%
artistData

# %%
alb = album()

# %%
baseURL = disc.discogURL

for (albums,artists) in zip(albumData,artistData):
    for album in albums:
        albumRef,albumName = getRefName(album)
        print(albumRef,'\t',albumName)
        try:
            albumID  = str(int(albumRef.split("/")[-1]))
        except:
            print("Could not get album ID from {0}".format(albumRef))
            albumID  = None
            
        print(albumID)
        url = urllib.parse.urljoin(baseURL, albumRef)
                
                
    for artist in artists:
        artistRef,artistName = getRefName(artist)        
        print(artistRef,'\t',artistName)

# %%
album

# %%
from searchUtils import findDirsPattern, findWalkExt
from fileUtils import getBaseFilename, getFileBasics
from ioUtils import saveFile, getFile
from timeUtils import clock, elapsed
from musicPath import pathBasics


##############################################################################################################################
# My Music
##############################################################################################################################
class musicFileAnalyzer(musicBase):
    def __init__(self, debug=False):
        self.name = "myfileanalyzer"
        musicBase.__init__(self, debug=debug)
        
        self.pb      = pathBasics()
        self.pathDBs = self.getMusicPathDBs()
        self.tagDBs  = self.getMusicTagDBs()

# %%
mfa = musicFileAnalyzer()

# %%
from fileUtils import getDirname
from collections import Counter

artistPathData = {}
albumPathData  = {}

for cls in ma.getMusicClasses():
    pathData = ma.getMusicPathDB(cls)
    tagData  = ma.getMusicTagDB(cls)
    
    start, cmt = clock("  Checking {0} mp3s".format(len(pathData)))
    for mp3,pb in pathData.items():
        
        artist = pb["pbArtist"]
        if artist is not None:
            if artistPathData.get(artist) is None:
                artistPathData[artist] = {}
        else:
            if artistPathData.get(artist) is None:
                artistPathData[artist] = {}

            
        album = pb["pbAlbum"]
        if album is not None:
            if artistPathData[artist].get(album) is None:
                artistPathData[artist][album] = {}
        else:
            if artistPathData[artist].get(album) is None:
                artistPathData[artist][album] = {}

            
        cls = pb["pbClass"]
        if album is not None:
            if artistPathData[artist][album].get(cls) is None:
                artistPathData[artist][album][cls] = {}
        else:
            if artistPathData[artist][album].get(cls) is None:
                artistPathData[artist][album][cls] = {}

                
        dirval = getDirname(mp3)
        
        if artistPathData[artist][album][cls].get(dirval) is None:
            artistPathData[artist][album][cls][dirval] = []
        artistPathData[artist][album][cls][dirval].append([pb, tagData[mp3]])
    elapsed(start, cmt)
    print("")
    
    
savename = setFile(ma.getDBDir(), "ArtistAlbumTagData.p")
saveFile(ifile=savename, idata=artistPathData, debug=True)

# %%
savename = setFile(ma.getDBDir(), "ArtistAlbumTagData.p")
artistPathData = getFile(savename)

# %%
nArt = 0
for artist,artistData in artistPathData.items():
    nArt += 1
    if nArt == 10:
        break
    for album,albumData in artistData.items():
        for cls,clsData in albumData.items():
            for dirval,dirvalData in clsData.items():
                
                dval = dirval.replace(ma.getMusicDir(), "")
                
                nFiles = len(dirvalData)
                partist = artist
                if len(artist) >= 40:
                    partist = "{0}...".format(artist[:36])
                palbum = album
                if len(album) >= 40:
                    palbum = "{0}...".format(album[:36])

                print("{0: <40}{1: <40}{2: <20}{3: <5}{4}".format(partist,palbum,cls,nFiles,dirval))

# %%
artistPathData

# %%
for ifile in ma.flists:
    tagfile  = ifile.replace(".p", "-Tags.p")
    pathfile = ifile.replace(".p", "-Paths.p")

    fileData = getFile(ifile)
    tagData  = getFile(tagfile)
    pathData = getFile(pathfile)

# %%
from searchUtils import findExt
files = findExt(basedir=ma.getDBDir(), ext="*.p")
files = [x for x in files if sum([y in x for y in ["Tags.p", "Paths.p"]]) == 0]
files

# %%
import os, sys
def splitall(path):
    allparts = []
    while 1:
        parts = os.path.split(path)
        if parts[0] == path:  # sentinel for absolute paths
            allparts.insert(0, parts[0])
            break
        elif parts[1] == path: # sentinel for relative paths
            allparts.insert(0, parts[1])
            break
        else:
            path = parts[0]
            allparts.insert(0, parts[1])
    return allparts

# %%
os.path.split("24 Shots/01 Intro (Power Of The Dollar)/dfd")

# %%
idir

# %%
files[-2]

# %%
ifile

# %%
filename

# %%
dirval

# %%
artist

# %%
# %load_ext autoreload
# %autoreload
disc = discogs()

# %%
import argparse as ap
from os import getcwd
from mp3id import mp3ID
mid = mp3ID(ifile)
minfo = mid.getInfo()
from glob import glob
from fsUtils import isFile
from fileUtils import getExt
from searchUtils import findWalkExt, findWalkPattern
from os import listdir, walk

class mp3Tagger:
    def __init__(self, disc=None):
        self.name = "mp3tagger"
        self.cwd  = getcwd()
        
        self.infos = {}
        self.ma       = multiArtist(cutoff=0.9, discdata=None, exact=False)

        
        if disc is not None:
            self.setDiscogs(disc)
        
        self.exts = mp3ID().mp3exts
        

    def setDiscogs(self, disc):
        artistDB = disc.getArtistVariationNameToIDsData()
        self.setArtistsDB(artistDB=artistDB)
        
    def setArtistsDB(self, artistDB, cutoff=0.9):
        self.ma       = multiArtist(cutoff=0.9, discdata=artistDB, exact=False)
        
        
    def getFiles(self, dirval):
        self.infos = {}
        files = findWalkPattern(basedir=dirval, pattern=".")
        files = [x for x in files if getExt(x) in self.exts]
        for i,ifile in enumerate(files):
            if self.infos.get(ifile) is None:
                mid = mp3ID(ifile)
                minfo = mid.getInfo()
                self.infos[ifile] = minfo
                
        
    def get(self):
        return self.infos
        
    def getInfo(self, dirval=None):
        if dirval is not None:
            self.getFiles(dirval)
            
        print("{0: <3}{1: <4}{2: <4}{3: <50}{4: <50}{5: <40}{6: <40}".format("#", "Trk", "Dsc", "Title", "Album", "Artist", "Album Artist"))

        i = 0
        for ifile,minfo in self.infos.items():
            print("{0: <3}".format(i+1), end="")

            trkno = minfo.get('TrackNo')
            if trkno is None:
                trkno = -1
            elif isinstance(trkno, list):
                if len(trkno) == 1:
                    trkno = trkno[0]
                else:
                    trkno = str(trkno)
            print("{0: <4}".format(trkno), end="")

            discno = minfo.get('DiscNo')
            if discno is None:
                discno = -1
            elif isinstance(discno, list):
                if len(discno) == 1:
                    discno = discno[0]
                else:
                    discno = str(discno)                
            print("{0: <4}".format(discno), end="")

            title = minfo.get('Title')
            if title is None:
                title = "?"
            elif isinstance(title, list):
                if len(title) == 1:
                    title = title[0]
                else:
                    title = str(title)
            print("{0: <50}".format(title), end="")

            album = minfo.get('Album')
            if album is None:
                album = "?"
            elif isinstance(album, list):
                if len(album) == 1:
                    album = album[0]
                else:
                    album = str(album)
            print("{0: <50}".format(album), end="")

            artist = minfo.get('Artist')
            if artist is None:
                artist = "?"
            elif isinstance(artist, list):
                if len(artist) == 1:
                    artist = artist[0]
                else:
                    artist = str(artist)
            print("{0: <40}".format(artist), end="")

            albartist = minfo.get('AlbumArtist')
            if albartist is None:
                albartist = "?"
            elif isinstance(albartist, list):
                if len(albartist) == 1:
                    albartist = albartist[0]
                else:
                    albartist = str(albartist)
            print("{0: <40}".format(albartist), end="")
            print("")
            
            i += 1
            
    

    def getAlbumArtists(self):
        return [x.get("AlbumArtist") for ifile,x in self.infos.items()]

# %%
mt = mp3Tagger(disc=disc)

# %%
mt.getInfo(dirval="/Volumes/Music/iTunes Jazz/iTunes Media/Music/Miles Davis & Quincy Jones")

# %%
from ioUtils import saveFile
retvals = {}
for ifile,minfo in mt.get().items():
    retvals[ifile] = {}

    for key in ["Artist", "AlbumArtist"]:
        val = minfo.get(key)
        if isinstance(val, list):
            if len(val) == 1:
                retval = mt.ma.getArtistNames(val[0])
                if len(retval) > 1:
                    artistNames = [k for k,v in retval.items() if v is not None]
                    retvals[ifile][key] = artistNames
                    
saveFile(idata=retvals, ifile="tmp.yaml")

# %%
retvals

# %%
tmp=[['Miles Davis & Quincy Jones'],
 ['Miles Davis & Quincy Jones'],
 ['Miles Davis & Quincy Jones'],
 ['Miles Davis & Quincy Jones'],
 ['Miles Davis & Quincy Jones'],
 ['Miles Davis & Quincy Jones'],
 ['Miles Davis & Quincy Jones'],
 ['Miles Davis & Quincy Jones'],
 ['Miles Davis & Quincy Jones'],
 ['Miles Davis & Quincy Jones'],
 ['Miles Davis & Quincy Jones'],
 ['Miles Davis & Quincy Jones'],
 ['Miles Davis & Quincy Jones'],
 ['Miles Davis & Quincy Jones'],
 ['Miles Davis & Quincy Jones'],
 ['Miles Davis & Quincy Jones']]

# %%
m.getDBDir

# %%
idir="/Volumes/Music/iTunes Jazz/iTunes Media/Music/Miles Davis & Quincy Jones


from random import shuffle
print("There are {0} chart artists".format(len(chartArtists)))
shuffle(chartArtists)
for i,artist in enumerate(chartArtists):
    if prevs.get(artist) is not None:
        continue
    retval = ma.getArtistNames(artist)
